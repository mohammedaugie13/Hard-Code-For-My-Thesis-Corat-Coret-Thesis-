# %%
from pyquil.quil import Program
import pyquil.api as api
from pyquil.gates import *
qvm = api.QVMConnection()
from pyquil.api import get_qc

# %%
def h2_a6_bk(x):
    
    p=Program()
    p+=X(0)
    #1
    p+=H(0)
    p+=RX(1.57,1)
    p+=H(2)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=RZ(x[0],2)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=H(0)
    p+=RX(-1.57,1)
    p+=H(2)
    #1.1
    p+=RX(1.57,0)
    p+=RX(1.57,1)
    p+=RX(1.57,2)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=RZ(x[0],2)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=RX(-1.57,0)
    p+=RX(-1.57,1)
    p+=RX(-1.57,2)
    
    #2
    p+=RX(1.57,1)
    p+=H(2)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=RZ(x[1],2)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=RX(-1.57,1)
    p+=H(2)
    #2.1
    p+=H(1)
    p+=RX(1.57,2)
    p+=CNOT(1,2)
    p+=RZ(x[1],2)
    p+=CNOT(1,2)
    p+=H(1)
    p+=RX(-1.57,2)
    
    #3
    p+=H(0)
    p+=RX(1.57,1)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=RZ(x[2],2)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=H(0)
    p+=RX(-1.57,1)
    #3.1
    p+=RX(1.57,0)
    p+=H(1)
    p+=CNOT(0,1)
    p+=CNOT(1,3)
    p+=RZ(x[2],3)
    p+=CNOT(1,3)
    p+=CNOT(0,1)
    p+=RX(-1.57,0)
    p+=H(1)
    
    #4
    p+=RX(1.57,1)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=RZ(x[3],2)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=RX(-1.57,1)
    #4.1
    p+=RX(1.57,1)
    p+=CNOT(1,3)
    p+=RZ(x[3],4)
    p+=CNOT(1,3)
    p+=RX(-1.57,1)
    
    #5
    p+=H(0)
    p+=RX(1.57,2)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=RZ(x[4],2)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=H(0)
    p+=RX(1.57,2)
    #5.1
    p+=H(0)
    p+=RX(1.57,2)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=CNOT(2,3)
    p+=RZ(x[4],3)
    p+=CNOT(2,3)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=H(0)
    p+=RX(-1.57,2)
    #5.2
    p+=H(0)
    p+=RX(1.57,2)
    p+=CNOT(0,2)
    p+=RZ(x[4],2)
    p+=CNOT(0,2)
    p+=H(0)
    p+=RX(-1.57,2)
    #5.3
    p+=H(0)
    p+=RX(1.57,2)
    p+=CNOT(0,2)
    p+=CNOT(2,3)
    p+=RZ(x[4],3)
    p+=CNOT(2,3)
    p+=CNOT(0,2)
    p+=H(0)
    p+=RX(-1.57,2)
    
    #5.4
    p+=RX(1.57,0)
    p+=H(2)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=RX(x[4],2)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=RX(-1.57,0)
    p+=H(2)
    #5.5
    p+=RX(1.57,0)
    p+=H(2)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=CNOT(2,3)
    p+=RZ(x[4],3)
    p+=CNOT(2,3)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=RX(-1.57,0)
    p+=H(2)
    #5.6
    p+=RX(1.57,0)
    p+=H(2)
    p+=CNOT(0,2)
    p+=RZ(x[4],2)
    p+=CNOT(0,2)
    p+=RX(-1.57,0)
    p+=H(2)
    #5.7
    p+=RX(1.57,0)
    p+=H(2)
    p+=CNOT(0,2)
    p+=CNOT(2,3)
    p+=RZ(x[4],3)
    p+=CNOT(2,3)
    p+=CNOT(0,2)
    p+=RX(-1.57,0)
    p+=H(2)
    
    
    #6
    p+=H(0)
    p+=RX(1.57,2)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=RZ(x[5],2)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=H(0)
    p+=RX(1.57,2)
    #6.1
    p+=H(0)
    p+=RX(1.57,2)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=CNOT(2,3)
    p+=RZ(x[5],3)
    p+=CNOT(2,3)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=H(0)
    p+=RX(-1.57,2)
    #6.2
    p+=H(0)
    p+=RX(1.57,2)
    p+=CNOT(0,2)
    p+=RZ(x[5],2)
    p+=CNOT(0,2)
    p+=H(0)
    p+=RX(-1.57,2)
    #6.3
    p+=H(0)
    p+=RX(1.57,2)
    p+=CNOT(0,2)
    p+=CNOT(2,3)
    p+=RZ(x[5],3)
    p+=CNOT(2,3)
    p+=CNOT(0,2)
    p+=H(0)
    p+=RX(-1.57,2)
    
    #6.4
    p+=RX(1.57,0)
    p+=H(2)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=RX(x[5],2)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=RX(-1.57,0)
    p+=H(2)
    #6.5
    p+=RX(1.57,0)
    p+=H(2)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=CNOT(2,3)
    p+=RZ(x[5],3)
    p+=CNOT(2,3)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=RX(-1.57,0)
    p+=H(2)
    #6.6
    p+=RX(1.57,0)
    p+=H(2)
    p+=CNOT(0,2)
    p+=RZ(x[5],2)
    p+=CNOT(0,2)
    p+=RX(-1.57,0)
    p+=H(2)
    #6.7
    p+=RX(1.57,0)
    p+=H(2)
    p+=CNOT(0,2)
    p+=CNOT(2,3)
    p+=RZ(x[5],3)
    p+=CNOT(2,3)
    p+=CNOT(0,2)
    p+=RX(-1.57,0)
    p+=H(2)
    
    #7
    p+=H(0)
    p+=H(1)
    p+=RX(1.57,3)
    p+=H(4)
    p+=CNOT(0,1)
    p+=CNOT(1,3)
    p+=CNOT(3,4)
    p+=RZ(x[6],4)
    p+=CNOT(3,4)
    p+=CNOT(1,3)
    p+=CNOT(0,1)
    p+=H(0)
    p+=H(1)
    p+=RX(-1.57,3)
    p+=H(4)
    #7.1
    p+=RX(1.57,0)
    p+=H(1)
    p+=RX(1.57,3)
    p+=RX(1.57,4)
    p+=CNOT(0,1)
    p+=CNOT(1,3)
    p+=CNOT(3,4)
    p+=RZ(x[6],4)
    p+=CNOT(3,4)
    p+=CNOT(1,3)
    p+=CNOT(0,1)
    p+=RX(-1.57,0)
    p+=H(1)
    p+=RX(-1.57,3)
    p+=RX(-1.57,4)
    
    #8
    p+=H(1)
    p+=RX(1.57,3)
    p+=H(4)
    p+=CNOT(0,1)
    p+=CNOT(1,3)
    p+=CNOT(3,4)
    p+=RZ(x[7],4)
    p+=CNOT(3,4)
    p+=CNOT(1,3)
    p+=CNOT(0,1)
    p+=H(1)
    p+=RX(-1.57,3)
    p+=H(4)
    #8.1
    p+=RX(1.57,1)
    p+=RX(1.57,3)
    p+=RX(1.57,4)
    p+=CNOT(1,3)
    p+=CNOT(3,4)
    p+=RZ(x[7],4)
    p+=CNOT(3,4)
    p+=CNOT(1,3)
    p+=RX(-1.57,1)
    p+=RX(-1.57,3)
    p+=RX(-1.57,4)
    
    #9
    p+=H(0)
    p+=H(1)
    p+=RX(1.57,3)
    p+=H(5)
    p+=CNOT(0,1)
    p+=CNOT(1,3)
    p+=CNOT(3,4)
    p+=CNOT(4,5)
    p+=RZ(x[8],5)
    p+=CNOT(4,5)
    p+=CNOT(3,4)
    p+=CNOT(1,3)
    p+=CNOT(0,1)
    p+=H(0)
    p+=H(1)
    p+=RX(-1.57,3)
    p+=H(5)
    
    #9.1
    p+=RX(1.57,0)
    p+=H(1)
    p+=RX(1.57,3)
    p+=RX(1.57,5)
    p+=CNOT(0,1)
    p+=CNOT(1,3)
    p+=CNOT(3,5)
    p+=RZ(x[8],5)
    p+=CNOT(3,5)
    p+=CNOT(1,3)
    p+=CNOT(0,1)
    p+=RX(-1.57,0)
    p+=H(1)
    p+=RX(-1.57,3)
    p+=RX(-1.57,5)
    
    #10
    p+=H(1)
    p+=RX(1.57,3)
    p+=H(5)
    p+=CNOT(0,1)
    p+=CNOT(1,3)
    p+=CNOT(3,4)
    p+=CNOT(4,5)
    p+=RZ(x[9],5)
    p+=CNOT(4,5)
    p+=CNOT(3,4)
    p+=CNOT(1,3)
    p+=CNOT(0,1)
    p+=H(1)
    p+=RX(-1.57,3)
    p+=H(5)
    
    #10.1
    p+=RX(1.57,1)
    p+=RX(1.57,3)
    p+=RX(1.57,5)
    p+=CNOT(1,3)
    p+=CNOT(3,5)
    p+=RZ(x[9],5)
    p+=CNOT(3,5)
    p+=CNOT(1,3)
    p+=RX(-1.57,1)
    p+=RX(-1.57,3)
    p+=RX(-1.57,5)
    
    #11
    p+=H(0)
    p+=RX(1.57,4)
    p+=CNOT(0,1)
    p+=CNOT(1,4)
    p+=RZ(x[10],4)
    p+=CNOT(1,4)
    p+=CNOT(0,1)
    p+=H(0)
    p+=RX(-1.57,4)
    
    #11.1
    p+=H(0)
    p+=RX(1.57,4)
    p+=CNOT(0,1)
    p+=CNOT(1,4)
    p+=CNOT(4,5)
    p+=RZ(x[10],5)
    p+=CNOT(4,5)
    p+=CNOT(1,4)
    p+=CNOT(0,1)
    p+=H(0)
    p+=RX(-1.57,4)
    
    #11.2
    p+=H(0)
    p+=RX(1.57,4)
    p+=CNOT(0,4)
    p+=RZ(x[10],4)
    p+=CNOT(0,4)
    p+=H(0)
    p+=RX(-1.57,4)
    
    #11.3
    p+=H(0)
    p+=RX(1.57,4)
    p+=CNOT(0,4)
    p+=CNOT(4,5)
    p+=RZ(x[10],5)
    p+=CNOT(4,5)
    p+=CNOT(0,4)
    p+=H(0)
    p+=RX(-1.57,4)
    
    #11.4
    p+=RX(1.57,0)
    p+=H(4)
    p+=CNOT(0,1)
    p+=CNOT(1,4)
    p+=RZ(x[10],4)
    p+=CNOT(1,4)
    p+=CNOT(0,1)
    p+=RX(-1.57,0)
    p+=H(4)
    
    #11.5
    p+=RX(1.57,0)
    p+=H(4)
    p+=CNOT(0,1)
    p+=CNOT(1,4)
    p+=CNOT(4,5)
    p+=RZ(x[10],5)
    p+=CNOT(4,5)
    p+=CNOT(1,4)
    p+=CNOT(0,1)
    p+=RX(-1.57,0)
    p+=H(4)

    #11.6
    p+=RX(1.57,0)
    p+=H(4)
    p+=CNOT(0,4)
    p+=RZ(x[10],4)
    p+=CNOT(0,4)
    p+=RX(-1.57,0)
    p+=H(4)
    
    #11.7
    p+=RX(1.57,0)
    p+=H(4)
    p+=CNOT(0,4)
    p+=CNOT(4,5)
    p+=RZ(x[10],5)
    p+=CNOT(4,5)
    p+=CNOT(0,4)
    p+=RX(-1.57,0)
    p+=H(4)
    
    
    #12
    p+=H(0)
    p+=RX(1.57,4)
    p+=CNOT(0,1)
    p+=CNOT(1,4)
    p+=RZ(x[11],4)
    p+=CNOT(1,4)
    p+=CNOT(0,1)
    p+=H(0)
    p+=RX(-1.57,4)
    
    #12.1
    p+=H(0)
    p+=RX(1.57,4)
    p+=CNOT(0,1)
    p+=CNOT(1,4)
    p+=CNOT(4,5)
    p+=RZ(x[11],5)
    p+=CNOT(4,5)
    p+=CNOT(1,4)
    p+=CNOT(0,1)
    p+=H(0)
    p+=RX(-1.57,4)
    
    #12.2
    p+=H(0)
    p+=RX(1.57,4)
    p+=CNOT(0,4)
    p+=RZ(x[11],4)
    p+=CNOT(0,4)
    p+=H(0)
    p+=RX(-1.57,4)
    
    #12.3
    p+=H(0)
    p+=RX(1.57,4)
    p+=CNOT(0,4)
    p+=CNOT(4,5)
    p+=RZ(x[11],5)
    p+=CNOT(4,5)
    p+=CNOT(0,4)
    p+=H(0)
    p+=RX(-1.57,4)
    
    #12.4
    p+=RX(1.57,0)
    p+=H(4)
    p+=CNOT(0,1)
    p+=CNOT(1,4)
    p+=RZ(x[11],4)
    p+=CNOT(1,4)
    p+=CNOT(0,1)
    p+=RX(-1.57,0)
    p+=H(4)
    
    #12.5
    p+=RX(1.57,0)
    p+=H(4)
    p+=CNOT(0,1)
    p+=CNOT(1,4)
    p+=CNOT(4,5)
    p+=RZ(x[11],5)
    p+=CNOT(4,5)
    p+=CNOT(1,4)
    p+=CNOT(0,1)
    p+=RX(-1.57,0)
    p+=H(4)

    #12.6
    p+=RX(1.57,0)
    p+=H(4)
    p+=CNOT(0,4)
    p+=RZ(x[11],4)
    p+=CNOT(0,4)
    p+=RX(-1.57,0)
    p+=H(4)
    
    #12.7
    p+=RX(1.57,0)
    p+=H(4)
    p+=CNOT(0,4)
    p+=CNOT(4,5)
    p+=RZ(x[11],5)
    p+=CNOT(4,5)
    p+=CNOT(0,4)
    p+=RX(-1.57,0)
    p+=H(4)
    
    
    
    
    
    return p

# %%
import openfermionpyscf as ofpyscf
import openfermion as of
from openfermion.transforms import *
from openfermion.utils import *
from openfermion.hamiltonians import MolecularData
import numpy as np
import pyscf

# %%
from openfermionpyscf import *
geometry = [["H", [0, 0, 0]],
            ["H", [0, 0, 0.7414]]]
basis = "6-31g"
multiplicity = 1
charge = 0
molecule = MolecularData(geometry, basis, multiplicity, charge)
h2_molecule = run_pyscf(molecule, run_mp2=True, run_cisd=True, run_ccsd=True, run_fci=True)
print(h2_molecule.ccsd_energy)
# Out:
# -1.1516828675117328

# %%
import openfermionpyscf as ofpyscf
from openfermion.ops import QubitOperator
from forestopenfermion import pyquilpauli_to_qubitop, qubitop_to_pyquilpauli
hamiltonian = ofpyscf.generate_molecular_hamiltonian(
    geometry, basis, multiplicity, charge)
qubit_operator=bravyi_kitaev(get_fermion_operator(hamiltonian))
hamiltonian_bk_pauli=qubitop_to_pyquilpauli(qubit_operator)

# %%
from grove.pyvqe.vqe import VQE
from scipy.optimize import minimize
import numpy as np

vqe_inst = VQE(minimizer=minimize,minimizer_kwargs={'method': 'nelder-mead'})

# %%
angle=np.linspace(0,0,12)
x = vqe_inst.vqe_run(h2_a6_bk, hamiltonian_bk_pauli, angle, None, qvm=qvm)
print(x)
# Out:
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# {'x': array([-0.00037216,  0.00524661, -0.0032305 , -0.00094041,  0.0316714 ,
#        -0.01747998, -0.00010161, -0.00012276, -0.00042127,  0.00112699,
#         0.00073757, -0.00171413]), 'fun': -1.13239176376052}

# %%
from pyquil.quil import Program
import pyquil.api as api
from pyquil.gates import *
qvm = api.QVMConnection()
from pyquil.api import get_qc

# %%
import openfermionpyscf as ofpyscf
import openfermion as of
from openfermion.transforms import *
from openfermion.utils import *
from openfermion.hamiltonians import MolecularData
from openfermion.ops import QubitOperator
from forestopenfermion import pyquilpauli_to_qubitop, qubitop_to_pyquilpauli
import numpy as np
import pyscf

# %%
def h2_a6_bk(x):
    
    p=Program()
    p+=X(0)
    #1
    p+=H(0)
    p+=RX(1.57,1)
    p+=H(2)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=RZ(x[0],2)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=H(0)
    p+=RX(-1.57,1)
    p+=H(2)
    #1.1
    p+=RX(1.57,0)
    p+=RX(1.57,1)
    p+=RX(1.57,2)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=RZ(x[0],2)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=RX(-1.57,0)
    p+=RX(-1.57,1)
    p+=RX(-1.57,2)
    
    #2
    p+=RX(1.57,1)
    p+=H(2)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=RZ(x[1],2)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=RX(-1.57,1)
    p+=H(2)
    #2.1
    p+=H(1)
    p+=RX(1.57,2)
    p+=CNOT(1,2)
    p+=RZ(x[1],2)
    p+=CNOT(1,2)
    p+=H(1)
    p+=RX(-1.57,2)
    
    #3
    p+=H(0)
    p+=RX(1.57,1)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=RZ(x[2],2)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=H(0)
    p+=RX(-1.57,1)
    #3.1
    p+=RX(1.57,0)
    p+=H(1)
    p+=CNOT(0,1)
    p+=CNOT(1,3)
    p+=RZ(x[2],3)
    p+=CNOT(1,3)
    p+=CNOT(0,1)
    p+=RX(-1.57,0)
    p+=H(1)
    
    #4
    p+=RX(1.57,1)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=RZ(x[3],2)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=RX(-1.57,1)
    #4.1
    p+=RX(1.57,1)
    p+=CNOT(1,3)
    p+=RZ(x[3],4)
    p+=CNOT(1,3)
    p+=RX(-1.57,1)
    
    #5
    p+=H(0)
    p+=RX(1.57,2)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=RZ(x[4],2)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=H(0)
    p+=RX(1.57,2)
    #5.1
    p+=H(0)
    p+=RX(1.57,2)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=CNOT(2,3)
    p+=RZ(x[4],3)
    p+=CNOT(2,3)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=H(0)
    p+=RX(-1.57,2)
    #5.2
    p+=H(0)
    p+=RX(1.57,2)
    p+=CNOT(0,2)
    p+=RZ(x[4],2)
    p+=CNOT(0,2)
    p+=H(0)
    p+=RX(-1.57,2)
    #5.3
    p+=H(0)
    p+=RX(1.57,2)
    p+=CNOT(0,2)
    p+=CNOT(2,3)
    p+=RZ(x[4],3)
    p+=CNOT(2,3)
    p+=CNOT(0,2)
    p+=H(0)
    p+=RX(-1.57,2)
    
    #5.4
    p+=RX(1.57,0)
    p+=H(2)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=RX(x[4],2)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=RX(-1.57,0)
    p+=H(2)
    #5.5
    p+=RX(1.57,0)
    p+=H(2)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=CNOT(2,3)
    p+=RZ(x[4],3)
    p+=CNOT(2,3)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=RX(-1.57,0)
    p+=H(2)
    #5.6
    p+=RX(1.57,0)
    p+=H(2)
    p+=CNOT(0,2)
    p+=RZ(x[4],2)
    p+=CNOT(0,2)
    p+=RX(-1.57,0)
    p+=H(2)
    #5.7
    p+=RX(1.57,0)
    p+=H(2)
    p+=CNOT(0,2)
    p+=CNOT(2,3)
    p+=RZ(x[4],3)
    p+=CNOT(2,3)
    p+=CNOT(0,2)
    p+=RX(-1.57,0)
    p+=H(2)
    
    
    #6
    p+=H(0)
    p+=RX(1.57,2)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=RZ(x[5],2)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=H(0)
    p+=RX(1.57,2)
    #6.1
    p+=H(0)
    p+=RX(1.57,2)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=CNOT(2,3)
    p+=RZ(x[5],3)
    p+=CNOT(2,3)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=H(0)
    p+=RX(-1.57,2)
    #6.2
    p+=H(0)
    p+=RX(1.57,2)
    p+=CNOT(0,2)
    p+=RZ(x[5],2)
    p+=CNOT(0,2)
    p+=H(0)
    p+=RX(-1.57,2)
    #6.3
    p+=H(0)
    p+=RX(1.57,2)
    p+=CNOT(0,2)
    p+=CNOT(2,3)
    p+=RZ(x[5],3)
    p+=CNOT(2,3)
    p+=CNOT(0,2)
    p+=H(0)
    p+=RX(-1.57,2)
    
    #6.4
    p+=RX(1.57,0)
    p+=H(2)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=RX(x[5],2)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=RX(-1.57,0)
    p+=H(2)
    #6.5
    p+=RX(1.57,0)
    p+=H(2)
    p+=CNOT(0,1)
    p+=CNOT(1,2)
    p+=CNOT(2,3)
    p+=RZ(x[5],3)
    p+=CNOT(2,3)
    p+=CNOT(1,2)
    p+=CNOT(0,1)
    p+=RX(-1.57,0)
    p+=H(2)
    #6.6
    p+=RX(1.57,0)
    p+=H(2)
    p+=CNOT(0,2)
    p+=RZ(x[5],2)
    p+=CNOT(0,2)
    p+=RX(-1.57,0)
    p+=H(2)
    #6.7
    p+=RX(1.57,0)
    p+=H(2)
    p+=CNOT(0,2)
    p+=CNOT(2,3)
    p+=RZ(x[5],3)
    p+=CNOT(2,3)
    p+=CNOT(0,2)
    p+=RX(-1.57,0)
    p+=H(2)
    
    #7
    p+=H(0)
    p+=H(1)
    p+=RX(1.57,3)
    p+=H(4)
    p+=CNOT(0,1)
    p+=CNOT(1,3)
    p+=CNOT(3,4)
    p+=RZ(x[6],4)
    p+=CNOT(3,4)
    p+=CNOT(1,3)
    p+=CNOT(0,1)
    p+=H(0)
    p+=H(1)
    p+=RX(-1.57,3)
    p+=H(4)
    #7.1
    p+=RX(1.57,0)
    p+=H(1)
    p+=RX(1.57,3)
    p+=RX(1.57,4)
    p+=CNOT(0,1)
    p+=CNOT(1,3)
    p+=CNOT(3,4)
    p+=RZ(x[6],4)
    p+=CNOT(3,4)
    p+=CNOT(1,3)
    p+=CNOT(0,1)
    p+=RX(-1.57,0)
    p+=H(1)
    p+=RX(-1.57,3)
    p+=RX(-1.57,4)
    
    #8
    p+=H(1)
    p+=RX(1.57,3)
    p+=H(4)
    p+=CNOT(0,1)
    p+=CNOT(1,3)
    p+=CNOT(3,4)
    p+=RZ(x[7],4)
    p+=CNOT(3,4)
    p+=CNOT(1,3)
    p+=CNOT(0,1)
    p+=H(1)
    p+=RX(-1.57,3)
    p+=H(4)
    #8.1
    p+=RX(1.57,1)
    p+=RX(1.57,3)
    p+=RX(1.57,4)
    p+=CNOT(1,3)
    p+=CNOT(3,4)
    p+=RZ(x[7],4)
    p+=CNOT(3,4)
    p+=CNOT(1,3)
    p+=RX(-1.57,1)
    p+=RX(-1.57,3)
    p+=RX(-1.57,4)
    
    #9
    p+=H(0)
    p+=H(1)
    p+=RX(1.57,3)
    p+=H(5)
    p+=CNOT(0,1)
    p+=CNOT(1,3)
    p+=CNOT(3,4)
    p+=CNOT(4,5)
    p+=RZ(x[8],5)
    p+=CNOT(4,5)
    p+=CNOT(3,4)
    p+=CNOT(1,3)
    p+=CNOT(0,1)
    p+=H(0)
    p+=H(1)
    p+=RX(-1.57,3)
    p+=H(5)
    
    #9.1
    p+=RX(1.57,0)
    p+=H(1)
    p+=RX(1.57,3)
    p+=RX(1.57,5)
    p+=CNOT(0,1)
    p+=CNOT(1,3)
    p+=CNOT(3,5)
    p+=RZ(x[8],5)
    p+=CNOT(3,5)
    p+=CNOT(1,3)
    p+=CNOT(0,1)
    p+=RX(-1.57,0)
    p+=H(1)
    p+=RX(-1.57,3)
    p+=RX(-1.57,5)
    
    #10
    p+=H(1)
    p+=RX(1.57,3)
    p+=H(5)
    p+=CNOT(0,1)
    p+=CNOT(1,3)
    p+=CNOT(3,4)
    p+=CNOT(4,5)
    p+=RZ(x[9],5)
    p+=CNOT(4,5)
    p+=CNOT(3,4)
    p+=CNOT(1,3)
    p+=CNOT(0,1)
    p+=H(1)
    p+=RX(-1.57,3)
    p+=H(5)
    
    #10.1
    p+=RX(1.57,1)
    p+=RX(1.57,3)
    p+=RX(1.57,5)
    p+=CNOT(1,3)
    p+=CNOT(3,5)
    p+=RZ(x[9],5)
    p+=CNOT(3,5)
    p+=CNOT(1,3)
    p+=RX(-1.57,1)
    p+=RX(-1.57,3)
    p+=RX(-1.57,5)
    
    #11
    p+=H(0)
    p+=RX(1.57,4)
    p+=CNOT(0,1)
    p+=CNOT(1,4)
    p+=RZ(x[10],4)
    p+=CNOT(1,4)
    p+=CNOT(0,1)
    p+=H(0)
    p+=RX(-1.57,4)
    
    #11.1
    p+=H(0)
    p+=RX(1.57,4)
    p+=CNOT(0,1)
    p+=CNOT(1,4)
    p+=CNOT(4,5)
    p+=RZ(x[10],5)
    p+=CNOT(4,5)
    p+=CNOT(1,4)
    p+=CNOT(0,1)
    p+=H(0)
    p+=RX(-1.57,4)
    
    #11.2
    p+=H(0)
    p+=RX(1.57,4)
    p+=CNOT(0,4)
    p+=RZ(x[10],4)
    p+=CNOT(0,4)
    p+=H(0)
    p+=RX(-1.57,4)
    
    #11.3
    p+=H(0)
    p+=RX(1.57,4)
    p+=CNOT(0,4)
    p+=CNOT(4,5)
    p+=RZ(x[10],5)
    p+=CNOT(4,5)
    p+=CNOT(0,4)
    p+=H(0)
    p+=RX(-1.57,4)
    
    #11.4
    p+=RX(1.57,0)
    p+=H(4)
    p+=CNOT(0,1)
    p+=CNOT(1,4)
    p+=RZ(x[10],4)
    p+=CNOT(1,4)
    p+=CNOT(0,1)
    p+=RX(-1.57,0)
    p+=H(4)
    
    #11.5
    p+=RX(1.57,0)
    p+=H(4)
    p+=CNOT(0,1)
    p+=CNOT(1,4)
    p+=CNOT(4,5)
    p+=RZ(x[10],5)
    p+=CNOT(4,5)
    p+=CNOT(1,4)
    p+=CNOT(0,1)
    p+=RX(-1.57,0)
    p+=H(4)

    #11.6
    p+=RX(1.57,0)
    p+=H(4)
    p+=CNOT(0,4)
    p+=RZ(x[10],4)
    p+=CNOT(0,4)
    p+=RX(-1.57,0)
    p+=H(4)
    
    #11.7
    p+=RX(1.57,0)
    p+=H(4)
    p+=CNOT(0,4)
    p+=CNOT(4,5)
    p+=RZ(x[10],5)
    p+=CNOT(4,5)
    p+=CNOT(0,4)
    p+=RX(-1.57,0)
    p+=H(4)
    
    
    #12
    p+=H(0)
    p+=RX(1.57,4)
    p+=CNOT(0,1)
    p+=CNOT(1,4)
    p+=RZ(x[11],4)
    p+=CNOT(1,4)
    p+=CNOT(0,1)
    p+=H(0)
    p+=RX(-1.57,4)
    
    #12.1
    p+=H(0)
    p+=RX(1.57,4)
    p+=CNOT(0,1)
    p+=CNOT(1,4)
    p+=CNOT(4,5)
    p+=RZ(x[11],5)
    p+=CNOT(4,5)
    p+=CNOT(1,4)
    p+=CNOT(0,1)
    p+=H(0)
    p+=RX(-1.57,4)
    
    #12.2
    p+=H(0)
    p+=RX(1.57,4)
    p+=CNOT(0,4)
    p+=RZ(x[11],4)
    p+=CNOT(0,4)
    p+=H(0)
    p+=RX(-1.57,4)
    
    #12.3
    p+=H(0)
    p+=RX(1.57,4)
    p+=CNOT(0,4)
    p+=CNOT(4,5)
    p+=RZ(x[11],5)
    p+=CNOT(4,5)
    p+=CNOT(0,4)
    p+=H(0)
    p+=RX(-1.57,4)
    
    #12.4
    p+=RX(1.57,0)
    p+=H(4)
    p+=CNOT(0,1)
    p+=CNOT(1,4)
    p+=RZ(x[11],4)
    p+=CNOT(1,4)
    p+=CNOT(0,1)
    p+=RX(-1.57,0)
    p+=H(4)
    
    #12.5
    p+=RX(1.57,0)
    p+=H(4)
    p+=CNOT(0,1)
    p+=CNOT(1,4)
    p+=CNOT(4,5)
    p+=RZ(x[11],5)
    p+=CNOT(4,5)
    p+=CNOT(1,4)
    p+=CNOT(0,1)
    p+=RX(-1.57,0)
    p+=H(4)

    #12.6
    p+=RX(1.57,0)
    p+=H(4)
    p+=CNOT(0,4)
    p+=RZ(x[11],4)
    p+=CNOT(0,4)
    p+=RX(-1.57,0)
    p+=H(4)
    
    #12.7
    p+=RX(1.57,0)
    p+=H(4)
    p+=CNOT(0,4)
    p+=CNOT(4,5)
    p+=RZ(x[11],5)
    p+=CNOT(4,5)
    p+=CNOT(0,4)
    p+=RX(-1.57,0)
    p+=H(4)
    
    
    
    
    
    return p

# %%
diatomic_bond_length = .7414
geometry = [('H', (0., 0., 0.)), ('H', (0., 0., diatomic_bond_length))]
basis = '631-g'
multiplicity = 1
charge = 0
description = str(diatomic_bond_length)

# %%
from grove.pyvqe.vqe import VQE
from scipy.optimize import minimize
import numpy as np

vqe_inst = VQE(minimizer=minimize,minimizer_kwargs={'method': 'nelder-mead'})

# %%
bond_length_interval = 0.1
n_points = 25

# %%
import openfermionpyscf as ofpyscf
from openfermionpyscf import *
import pyscf
import numpy as np
ccsd_energies = []
fci_energies=[]
vqe_uccsd_energies = []
bond_lengths = []
hf_energies=[]
E=[]
angle=np.linspace(0,0,12)
for point in range(3, n_points + 1):
    bond_length = bond_length_interval * point
    bond_lengths += [bond_length]
    description = str(round(bond_length,2))
    #print("Jarak Antar Atom=",description)
    geometry = [('H', (0., 0., 0.)), ('H', (0., 0., bond_length))]
    molecule1 = MolecularData(geometry, basis, multiplicity, description=description)
    h2_molecule = run_pyscf(molecule1, run_mp2=True, run_cisd=True, run_ccsd=True, run_fci=True)
    hamiltonian = ofpyscf.generate_molecular_hamiltonian(geometry, basis, multiplicity, charge)
    hamiltonan_bk=bravyi_kitaev(get_fermion_operator(hamiltonian))
    hamiltonian_bk_pauli=qubitop_to_pyquilpauli(hamiltonan_bk)
    
    x= vqe_inst.vqe_run(h2_a6_bk, hamiltonian_bk_pauli, angle, None, qvm=qvm)
    E.append(x.fun)
    ccsd_energies += [h2_molecule.ccsd_energy]
    fci_energies += [h2_molecule.fci_energy]
    hf_energies += [h2_molecule.hf_energy]
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(0)
plt.plot(bond_lengths, ccsd_energies, 'b-')
plt.plot(bond_lengths, E, 'c--*')
plt.plot(bond_lengths, fci_energies,'rx')
plt.plot(bond_lengths,hf_energies,'y--*')
plt.grid()
plt.ylabel('Energi  (Hartree)')
plt.xlabel('Bond length  (Angstrom)')
plt.show()
# Out:
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective
# WARNING: Fast method for expectation will be used. Noise
#                      models will be ineffective

# %%
plt.figure(0)
plt.title('Energi Vs Jarak (AS 6)')
plt.plot(bond_lengths, ccsd_energies, 'b-',label='Energi CCSD')
plt.plot(bond_lengths, E, 'c--*',label='Energi UCCSD')
plt.plot(bond_lengths, fci_energies,'rx', label='Energi FCI')
plt.plot(bond_lengths,hf_energies,'y--*',label='Energi HF')
plt.grid()
plt.ylabel('Energi  (Hartree)')
plt.xlabel('Jarak antar Atom  (Angstrom)')
plt.legend()
plt.show()
plt.savefig('Energi_Vs_Jarak_AS_6_BK',format='png')

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.semilogy(bond_lengths,np.abs(np.subtract(fci_energies,hf_energies)),label='Energi HF')
plt.semilogy(bond_lengths,np.abs(np.subtract(fci_energies,ccsd_energies)),label='Energi CCSD')
plt.semilogy(bond_lengths,np.abs(np.subtract(fci_energies,E)),label='Energi UCCSD')
plt.semilogy(bond_lengths,0.0016*np.ones([len(bond_lengths),1]),label='Chemical Accuracy',linestyle='-.',color='black')
plt.xlabel('Jarak Antar Molekul (Angstrom)')
plt.ylabel('Energi Eror Terhadap FCI (Hartree)')
plt.title('Error Terhadap FCI (AS 6)')
plt.savefig('Error Terhadap FCI (AS 6) Cobyla',format='png')

plt.legend()

# %%
from pyquil.quil import Program
import pyquil.api as api
from pyquil.gates import *
qvm = api.QVMConnection()
from pyquil.api import get_qc

# %%
def h2_jw(x):
       #1
    prog=Program()
    prog+=X(0)
    prog+=X(1)
    prog+=H(0)
    prog+=H(1)
    prog+=H(2)
    prog+=RX(1.57,3)
    prog+=CNOT(0,1)
    prog+=CNOT(1,2)
    prog+=CNOT(2,3)
    prog+=RZ(x[0],3)
    prog+=CNOT(2,3)
    prog+=CNOT(1,2)
    prog+=CNOT(0,1)
    prog+=H(0)
    prog+=H(1)
    prog+=H(2)
    prog+=RX(-1.57,3)
    #2
    prog+=H(0)
    prog+=H(1)
    prog+=RX(1.57,2)
    prog+=H(3)
    prog+=CNOT(0,1)
    prog+=CNOT(1,2)
    prog+=CNOT(2,3)
    prog+=RZ(x[0],3)
    prog+=CNOT(2,3)
    prog+=CNOT(1,2)
    prog+=CNOT(0,1)
    prog+=H(0)
    prog+=H(1)
    prog+=RX(-1.57,2)
    prog+=H(3)
    #3
    prog+=H(0)
    prog+=RX(1.57,1)
    prog+=H(2)
    prog+=H(3)
    prog+=CNOT(0,1)
    prog+=CNOT(1,2)
    prog+=CNOT(2,3)
    prog+=RZ(x[1],3)
    prog+=CNOT(2,3)
    prog+=CNOT(1,2)
    prog+=CNOT(0,1)
    prog+=H(0)
    prog+=RX(-1.57,1)
    prog+=H(2)
    prog+=H(3)
    
    #4
    prog+=H(0)
    prog+=RX(1.57,1)
    prog+=RX(1.57,2)
    prog+=RX(1.57,3)
    prog+=CNOT(0,1)
    prog+=CNOT(1,2)
    prog+=CNOT(2,3)
    prog+=RZ(x[0],3)
    prog+=CNOT(2,3)
    prog+=CNOT(1,2)
    prog+=CNOT(0,1)
    prog+=H(0)
    prog+=RX(-1.57,1)
    prog+=RX(-1.57,2)
    prog+=RX(-1.57,3)
    
    
    #5
    prog+=RX(1.57,0)
    prog+=H(1)
    prog+=H(2)
    prog+=H(3)
    prog+=CNOT(0,1)
    prog+=CNOT(1,2)
    prog+=CNOT(2,3)
    prog+=RZ(x[1],3)
    prog+=CNOT(2,3)
    prog+=CNOT(1,2)
    prog+=CNOT(0,1)
    prog+=RX(-1.57,0)
    prog+=H(1)
    prog+=H(2)
    prog+=H(3)
    
    #6
    prog+=RX(1.57,0)
    prog+=H(1)
    prog+=RX(1.57,2)
    prog+=RX(1.57,3)
    prog+=CNOT(0,1)
    prog+=CNOT(1,2)
    prog+=CNOT(2,3)
    prog+=RZ(x[0],3)
    prog+=CNOT(2,3)
    prog+=CNOT(1,2)
    prog+=CNOT(0,1)
    prog+=RX(-1.57,0)
    prog+=H(1)
    prog+=RX(-1.57,2)
    prog+=RX(-1.57,3)
    
    #7
    prog+=RX(1.57,0)
    prog+=RX(1.57,1)
    prog+=H(2)
    prog+=RX(1.57,3)
    prog+=CNOT(0,1)
    prog+=CNOT(1,2)
    prog+=CNOT(2,3)
    prog+=RZ(x[1],3)
    prog+=CNOT(2,3)
    prog+=CNOT(1,2)
    prog+=CNOT(0,1)
    prog+=RX(-1.57,0)
    prog+=RX(-1.57,1)
    prog+=H(2)
    prog+=RX(-1.57,3)
    
    #8
    prog+=RX(1.57,0)
    prog+=RX(1.57,1)
    prog+=RX(1.57,2)
    prog+=H(3)
    prog+=CNOT(0,1)
    prog+=CNOT(1,2)
    prog+=CNOT(2,3)
    prog+=RZ(x[1],3)
    prog+=CNOT(2,3)
    prog+=CNOT(1,2)
    prog+=CNOT(0,1)
    prog+=RX(-1.57,0)
    prog+=RX(-1.57,1)
    prog+=RX(-1.57,2)
    prog+=H(3)
    
    return prog

# %%
import openfermionpyscf as ofpyscf
from openfermion.ops import QubitOperator
from forestopenfermion import pyquilpauli_to_qubitop, qubitop_to_pyquilpauli
z0 = QubitOperator('Z0') #1
z1 = QubitOperator('Z1') #2
z2=QubitOperator('Z2') #3
z3=QubitOperator('Z3') #4
z0z1=QubitOperator('Z0 Z1') #5
z0z2=QubitOperator('Z0 Z2') #6
z0z3=QubitOperator('Z0 Z3') #7 
z1z2=QubitOperator('Z1 Z2') #8
z1z3=QubitOperator('Z1 Z3') #9 
z2z3=QubitOperator('Z2 Z3') #10
x0x1y2y3=QubitOperator('X0 X1 Y2 Y3') #11
x0y1y2x3=QubitOperator('X0 Y1 Y2 X3') #12
y0x1x2y3=QubitOperator('Y0 X1 X2 Y3') #13
y0y1x2x3=QubitOperator('Y0 Y1 X2 X3') #14


z0_pauli = qubitop_to_pyquilpauli(z0) #1

z1_pauli = qubitop_to_pyquilpauli(z1) #2

z2_pauli=qubitop_to_pyquilpauli(z2) #3

z3_pauli=qubitop_to_pyquilpauli(z3) #4

z0z1_pauli=qubitop_to_pyquilpauli(z0z1) #5

z0z2_pauli=qubitop_to_pyquilpauli(z0z2) #6

z0z3_pauli=qubitop_to_pyquilpauli(z0z3) #7

z1z2_pauli=qubitop_to_pyquilpauli(z1z2) #8

z1z3_pauli=qubitop_to_pyquilpauli(z1z3) #9

z2z3_pauli=qubitop_to_pyquilpauli(z2z3) #10

x0x1y2y3_pauli=qubitop_to_pyquilpauli(x0x1y2y3) #11

x0y1y2x3_pauli=qubitop_to_pyquilpauli(x0y1y2x3) #12

y0x1x2y3_pauli=qubitop_to_pyquilpauli(y0x1x2y3) #13

y0y1x2x3_pauli=qubitop_to_pyquilpauli(y0y1x2x3) #14

# %%
from grove.pyvqe.vqe import VQE
from scipy.optimize import minimize
import numpy as np

vqe_inst = VQE(minimizer=minimize,minimizer_kwargs={'method': 'nelder-mead'})

# %%
import numpy as np

thetas1 = np.linspace(0,6,100)
thetas2 = np.linspace(0,6,100)

E_z0=[]
for x in thetas1:
    for y in thetas2:
        param=[x,y]
        E_z0.append(vqe_inst.expectation(h2_jw(param), z0_pauli, None, qvm))

# %%
E=np.array(E_z0).reshape(100,100)
E_z0=E.transpose()

# %%
from matplotlib import rc
import matplotlib.pyplot as plt
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.imshow(E_z0,cmap='gist_heat_r',extent=[0,6,0,6])
plt.colorbar()
plt.xlabel(r'$\theta_1$',fontsize=16)
plt.ylabel(r'$\theta_2$',fontsize=16)
plt.title(r'$<Z0>$',fontsize=20)
plt.savefig('Z0_h2_jw_full',format='png')

# %%
import numpy as np

thetas1 = np.linspace(0,6,100)
thetas2 = np.linspace(0,6,100)

E_z1=[]
for x in thetas1:
    for y in thetas2:
        param=[x,y]
        E_z1.append(vqe_inst.expectation(h2_jw(param), z1_pauli, None, qvm))

# %%
E=np.array(E_z1).reshape(100,100)
E_z1=E.transpose()
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.imshow(E_z1,cmap='gist_heat_r',extent=[0,6,0,6])
plt.colorbar()
plt.xlabel(r'$\theta_1$',fontsize=16)
plt.ylabel(r'$\theta_2$',fontsize=16)
plt.title(r'$<Z1>$',fontsize=20)
plt.savefig('Z1_h2_jw_full',format='png')

# %%
import numpy as np

thetas1 = np.linspace(0,6,100)
thetas2 = np.linspace(0,6,100)

E_z2=[]
for x in thetas1:
    for y in thetas2:
        param=[x,y]
        E_z2.append(vqe_inst.expectation(h2_jw(param), z2_pauli, None, qvm))

# %%
E=np.array(E_z2).reshape(100,100)
E_z2=E.transpose()
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.imshow(E_z2,cmap='gist_heat_r',extent=[0,6,0,6])
plt.colorbar()
plt.xlabel(r'$\theta_1$',fontsize=16)
plt.ylabel(r'$\theta_2$',fontsize=16)
plt.title(r'$<Z2>$',fontsize=20)
plt.savefig('Z2_h2_jw_full',format='png')

# %%
import numpy as np

thetas1 = np.linspace(0,6,100)
thetas2 = np.linspace(0,6,100)

E_z3=[]
for x in thetas1:
    for y in thetas2:
        param=[x,y]
        E_z3.append(vqe_inst.expectation(h2_jw(param), z3_pauli, None, qvm))

# %%
E=np.array(E_z3).reshape(100,100)
E_z3=E.transpose()
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.imshow(E_z3,cmap='gist_heat_r',extent=[0,6,0,6])
plt.colorbar()
plt.xlabel(r'$\theta_1$',fontsize=16)
plt.ylabel(r'$\theta_2$',fontsize=16)
plt.title(r'$<Z3>$',fontsize=20)
plt.savefig('Z3_h2_jw_full',format='png')

# %%
import numpy as np

thetas1 = np.linspace(0,6,100)
thetas2 = np.linspace(0,6,100)

E_z0z1=[]
for x in thetas1:
    for y in thetas2:
        param=[x,y]
        E_z0z1.append(vqe_inst.expectation(h2_jw(param), z0z1_pauli, None, qvm))

# %%
E=np.array(E_z0z1).reshape(100,100)
E_z0z1=E.transpose()
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.imshow(E_z0z1,cmap='gist_heat_r',extent=[0,6,0,6])
plt.colorbar()
plt.xlabel(r'$\theta_1$',fontsize=16)
plt.ylabel(r'$\theta_2$',fontsize=16)
plt.title(r'$<Z0 \quad Z1>$',fontsize=20)
plt.savefig('Z0Z1_h2_jw_full',format='png')

# %%
import numpy as np

thetas1 = np.linspace(0,6,100)
thetas2 = np.linspace(0,6,100)

E_z0z2=[]
for x in thetas1:
    for y in thetas2:
        param=[x,y]
        E_z0z2.append(vqe_inst.expectation(h2_jw(param), z0z2_pauli, None, qvm))

# %%
E=np.array(E_z0z2).reshape(100,100)
E_z0z2=E.transpose()
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.imshow(E_z0z2,cmap='gist_heat_r',extent=[0,6,0,6])
plt.colorbar()
plt.xlabel(r'$\theta_1$',fontsize=16)
plt.ylabel(r'$\theta_2$',fontsize=16)
plt.title(r'$<Z0  Z2>$',fontsize=20)
plt.savefig('Z0Z2_h2_jw_full',format='png')

# %%
import numpy as np

thetas1 = np.linspace(0,6,100)
thetas2 = np.linspace(0,6,100)

E_z0z3=[]
for x in thetas1:
    for y in thetas2:
        param=[x,y]
        E_z0z3.append(vqe_inst.expectation(h2_jw(param), z0z3_pauli, None, qvm))

# %%
E=np.array(E_z0z3).reshape(100,100)
E_z0z3=E.transpose()
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.imshow(E_z0z3,cmap='gist_heat_r',extent=[0,6,0,6])
plt.colorbar()
plt.xlabel(r'$\theta_1$',fontsize=16)
plt.ylabel(r'$\theta_2$',fontsize=16)
plt.title(r'$<Z0  Z3>$',fontsize=20)
plt.savefig('Z0Z3_h2_jw_full',format='png')

# %%
print(E_z0z3)
# Out:
# [[-1.         -0.99999999 -0.99999995 ... -0.99999954 -0.99999965
#   -0.99999976]
#  [-0.99999999 -0.99999999 -0.99999997 ... -0.99999945 -0.99999957
#   -0.99999969]
#  [-0.99999995 -0.99999997 -0.99999996 ... -0.99999934 -0.99999947
#   -0.9999996 ]
#  ...
#  [-0.99999954 -0.99999945 -0.99999934 ... -0.99999961 -0.99999965
#   -0.99999968]
#  [-0.99999965 -0.99999957 -0.99999947 ... -0.99999965 -0.99999971
#   -0.99999975]
#  [-0.99999976 -0.99999969 -0.9999996  ... -0.99999968 -0.99999975
#   -0.9999998 ]]

# %%
import numpy as np

thetas1 = np.linspace(0,6,100)
thetas2 = np.linspace(0,6,100)

E_z1z2=[]
for x in thetas1:
    for y in thetas2:
        param=[x,y]
        E_z1z2.append(vqe_inst.expectation(h2_jw(param), z1z2_pauli, None, qvm))

# %%
E=np.array(E_z1z2).reshape(100,100)
E_z1z2=E.transpose()
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.imshow(E_z1z2,cmap='gist_heat_r',extent=[0,6,0,6])
plt.colorbar()
plt.xlabel(r'$\theta_1$',fontsize=16)
plt.ylabel(r'$\theta_2$',fontsize=16)
plt.title(r'$<Z1  Z2>$',fontsize=20)
plt.savefig('Z1Z2_h2_jw_full',format='png')
print(E_z1z2)
# Out:
# [[-1.         -0.99999999 -0.99999995 ... -0.99999954 -0.99999965
#   -0.99999976]
#  [-0.99999999 -0.99999999 -0.99999997 ... -0.99999945 -0.99999957
#   -0.99999969]
#  [-0.99999995 -0.99999997 -0.99999996 ... -0.99999934 -0.99999947
#   -0.9999996 ]
#  ...
#  [-0.99999954 -0.99999945 -0.99999934 ... -0.99999961 -0.99999965
#   -0.99999968]
#  [-0.99999965 -0.99999957 -0.99999947 ... -0.99999965 -0.99999971
#   -0.99999975]
#  [-0.99999976 -0.99999969 -0.9999996  ... -0.99999968 -0.99999975
#   -0.9999998 ]]

# %%
import numpy as np

thetas1 = np.linspace(0,6,100)
thetas2 = np.linspace(0,6,100)

E_z1z3=[]
for x in thetas1:
    for y in thetas2:
        param=[x,y]
        E_z1z3.append(vqe_inst.expectation(h2_jw(param), z1z3_pauli, None, qvm))

# %%
E=np.array(E_z1z3).reshape(100,100)
E_z1z3=E.transpose()
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.imshow(E_z1z3,cmap='gist_heat_r',extent=[0,6,0,6])
plt.colorbar()
plt.xlabel(r'$\theta_1$',fontsize=16)
plt.ylabel(r'$\theta_2$',fontsize=16)
plt.title(r'$<Z1  Z3>$',fontsize=20)
plt.savefig('Z1Z3_h2_jw_full',format='png')

# %%
import numpy as np

thetas1 = np.linspace(0,6,100)
thetas2 = np.linspace(0,6,100)

E_z2z3=[]
for x in thetas1:
    for y in thetas2:
        param=[x,y]
        E_z2z3.append(vqe_inst.expectation(h2_jw(param), z2z3_pauli, None, qvm))

# %%
E=np.array(E_z2z3).reshape(100,100)
E_z2z3=E.transpose()
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.imshow(E_z2z3,cmap='gist_heat_r',extent=[0,6,0,6])
plt.colorbar()
plt.xlabel(r'$\theta_1$',fontsize=16)
plt.ylabel(r'$\theta_2$',fontsize=16)
plt.title(r'$<Z2  Z3>$',fontsize=20)
plt.savefig('Z2Z3_h2_jw_full',format='png')

# %%
import numpy as np

thetas1 = np.linspace(0,6,100)
thetas2 = np.linspace(0,6,100)

E_x0x1y2y3=[]
for x in thetas1:
    for y in thetas2:
        param=[x,y]
        E_x0x1y2y3.append(vqe_inst.expectation(h2_jw(param), x0x1y2y3_pauli, None, qvm))

# %%
E=np.array(E_x0x1y2y3).reshape(100,100)
E_x0x1y2y3=E.transpose()
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.imshow(E_x0x1y2y3,cmap='gist_heat_r',extent=[0,6,0,6])
plt.colorbar()
plt.xlabel(r'$\theta_1$',fontsize=16)
plt.ylabel(r'$\theta_2$',fontsize=16)
plt.title(r'$<X0 X1 Y2 Y3>$',fontsize=20)
plt.savefig('x0x1y2y3_h2_jw_full',format='png')

# %%
import numpy as np

thetas1 = np.linspace(0,6,100)
thetas2 = np.linspace(0,6,100)

E_x0y1y2x3=[]
for x in thetas1:
    for y in thetas2:
        param=[x,y]
        E_x0y1y2x3.append(vqe_inst.expectation(h2_jw(param), x0y1y2x3_pauli, None, qvm))

# %%
E=np.array(E_x0y1y2x3).reshape(100,100)
E_x0y1y2x3=E.transpose()
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.imshow(E_x0y1y2x3,cmap='gist_heat_r',extent=[0,6,0,6])
plt.colorbar()
plt.xlabel(r'$\theta_1$',fontsize=16)
plt.ylabel(r'$\theta_2$',fontsize=16)
plt.title(r'$<X0 Y1 Y2 X3>$',fontsize=20)
plt.savefig('x0y1y2x3_h2_jw_full',format='png')

# %%
import numpy as np

thetas1 = np.linspace(0,6,100)
thetas2 = np.linspace(0,6,100)

E_y0x1x2y3=[]
for x in thetas1:
    for y in thetas2:
        param=[x,y]
        E_y0x1x2y3.append(vqe_inst.expectation(h2_jw(param), y0x1x2y3_pauli, None, qvm))

# %%
E=np.array(E_y0x1x2y3).reshape(100,100)
E_y0x1x2y3=E.transpose()
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.imshow(E_y0x1x2y3,cmap='gist_heat_r',extent=[0,6,0,6])
plt.colorbar()
plt.xlabel(r'$\theta_1$',fontsize=16)
plt.ylabel(r'$\theta_2$',fontsize=16)
plt.title(r'$<Y0 X1 X2 Y3>$',fontsize=20)
plt.savefig('y0x1x2y3_h2_jw_full',format='png')

# %%
import numpy as np

thetas1 = np.linspace(0,6,100)
thetas2 = np.linspace(0,6,100)

E_y0y1x2x3=[]
for x in thetas1:
    for y in thetas2:
        param=[x,y]
        E_y0y1x2x3.append(vqe_inst.expectation(h2_jw(param), y0y1x2x3_pauli, None, qvm))

# %%
E=np.array(E_y0y1x2x3).reshape(100,100)
E_y0y1x2x3=E.transpose()
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.imshow(E_y0y1x2x3,cmap='gist_heat_r',extent=[0,6,0,6])
plt.colorbar()
plt.xlabel(r'$\theta_1$',fontsize=16)
plt.ylabel(r'$\theta_2$',fontsize=16)
plt.title(r'$<Y0 Y1 X2 X3>$',fontsize=20)
plt.savefig('y0y1x2x3_h2_jw_full',format='png')

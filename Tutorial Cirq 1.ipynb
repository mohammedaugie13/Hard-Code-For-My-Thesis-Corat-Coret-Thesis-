# %%
import openfermion as of

# Set Hubbard model parameters
x_dim = 2
y_dim = 3
tunneling = 1.0
coulomb = 4.0
spinless=True

# Create Hubbard model Hamiltonian as FermionOperator
hubbard_model = of.fermi_hubbard(x_dim, y_dim, tunneling, coulomb, spinless=spinless)
print(hubbard_model)
# Out:
# 4.0 [0^ 0 1^ 1] +
# 4.0 [0^ 0 2^ 2] +
# -1.0 [0^ 1] +
# -1.0 [0^ 2] +
# -1.0 [0^ 4] +
# -1.0 [1^ 0] +
# 4.0 [1^ 1 3^ 3] +
# -1.0 [1^ 3] +
# -1.0 [1^ 5] +
# -1.0 [2^ 0] +
# 4.0 [2^ 2 3^ 3] +
# 4.0 [2^ 2 4^ 4] +
# -1.0 [2^ 3] +
# -1.0 [2^ 4] +
# -1.0 [3^ 1] +
# -1.0 [3^ 2] +
# 4.0 [3^ 3 5^ 5] +
# -1.0 [3^ 5] +
# -1.0 [4^ 0] +
# -1.0 [4^ 2] +
# 4.0 [4^ 4 0^ 0] +
# 4.0 [4^ 4 5^ 5] +
# -1.0 [4^ 5] +
# -1.0 [5^ 1] +
# -1.0 [5^ 3] +
# -1.0 [5^ 4] +
# 4.0 [5^ 5 1^ 1]

# %%
from scipy.sparse.linalg import expm_multiply

# Create a random initial state
n_qubits = of.count_qubits(hubbard_model)
initial_state = of.haar_random_vector(2**n_qubits, seed=7)

# Convert Hamiltonian to sparse matrix
hubbard_sparse = of.get_sparse_operator(of.jordan_wigner(hubbard_model))

# Set evolution time
time = 1.0

# Apply exp(-i H t) to the state
exact_state = expm_multiply(-1j*hubbard_sparse*time, initial_state)
print(hubbard_sparse)
# Out:
#   (2, 1)	(-1+0j)
#   (4, 1)	(-1+0j)
#   (16, 1)	(-1+0j)
#   (1, 2)	(-1+0j)
#   (8, 2)	(-1+0j)
#   (32, 2)	(-1+0j)
#   (3, 3)	(4+0j)
#   (6, 3)	(1+0j)
#   (9, 3)	(-1+0j)
#   (18, 3)	(1+0j)
#   (33, 3)	(-1+0j)
#   (1, 4)	(-1+0j)
#   (8, 4)	(-1+0j)
#   (16, 4)	(-1+0j)
#   (5, 5)	(4+0j)
#   (6, 5)	(-1+0j)
#   (9, 5)	(-1+0j)
#   (17, 5)	(-1+0j)
#   (20, 5)	(1+0j)
#   (3, 6)	(1+0j)
#   (5, 6)	(-1+0j)
#   (10, 6)	(-1+0j)
#   (12, 6)	(1+0j)
#   (18, 6)	(-1+0j)
#   (36, 6)	(1+0j)
#   :	:
#   (58, 57)	(-1+0j)
#   (60, 57)	(-1+0j)
#   (43, 58)	(-1+0j)
#   (46, 58)	(1+0j)
#   (54, 58)	(-1+0j)
#   (57, 58)	(-1+0j)
#   (58, 58)	(16+0j)
#   (47, 59)	(1+0j)
#   (55, 59)	(-1+0j)
#   (59, 59)	(24+0j)
#   (62, 59)	(1+0j)
#   (30, 60)	(1+0j)
#   (45, 60)	(-1+0j)
#   (54, 60)	(1+0j)
#   (57, 60)	(-1+0j)
#   (60, 60)	(16+0j)
#   (31, 61)	(1+0j)
#   (55, 61)	(1+0j)
#   (61, 61)	(24+0j)
#   (62, 61)	(-1+0j)
#   (47, 62)	(1+0j)
#   (59, 62)	(1+0j)
#   (61, 62)	(-1+0j)
#   (62, 62)	(24+0j)
#   (63, 63)	(36+0j)

# %%
import cirq
import openfermioncirq as ofc
import numpy as np

# Convert Hamiltonian to a DiagonalCoulombHamiltonian instance
hubbard_hamiltonian = of.get_diagonal_coulomb_hamiltonian(hubbard_model)

# Initialize qubits
qubits = cirq.LineQubit.range(n_qubits)

# Create circuit
circuit = cirq.Circuit.from_ops(
    ofc.simulate_trotter(
        qubits, hubbard_hamiltonian, time,
        n_steps=10,
        order=0,
        algorithm=ofc.trotter.LINEAR_SWAP_NETWORK)
)

# Apply the circuit to the initial state
result = circuit.apply_unitary_effect_to_state(initial_state)

# Compute the fidelity with the final state from exact evolution
fidelity = abs(np.dot(exact_state, result.conj()))**2

print(fidelity)
print(circuit)
# Out:
# 0.9732473269809888
# 0: ───XXYY──────────YXXY───@──────────×ᶠ──────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────Rz(-0.0π)───────────────────────────────────────────────────────────────────────XXYY──────────#2───────@──────────×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY──────────#2───────@──────────×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY──────────#2───────@──────────×ᶠ──────────────────────────────────────────────Rz(-0.0π)───────────────XXYY──────────YXXY───@──────────×ᶠ──────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────Rz(-0.0π)───────────────────────────────────────────────────────────────────────XXYY──────────#2───────@──────────×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY──────────#2───────@──────────×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY──────────#2───────@──────────×ᶠ──────────────────────────────────────────────Rz(-0.0π)───────────────XXYY──────────YXXY───@──────────×ᶠ──────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────Rz(-0.0π)───────────────────────────────────────────────────────────────────────XXYY──────────#2───────@──────────×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY──────────#2───────@──────────×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY──────────#2───────@──────────×ᶠ──────────────────────────────────────────────Rz(-0.0π)───────────────XXYY──────────YXXY───@──────────×ᶠ──────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────Rz(-0.0π)───────────────────────────────────────────────────────────────────────XXYY──────────#2───────@──────────×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY──────────#2───────@──────────×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY──────────#2───────@──────────×ᶠ──────────────────────────────────────────────Rz(-0.0π)───────────────XXYY──────────YXXY───@──────────×ᶠ──────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY──────────YXXY───@────────── ...
#       │             │      │          │                                                                                                           │             │      │          │                                                                                                                     │             │      │          │                                                                                                                                                                                             │             │        │          │                                                                                                         │             │        │          │                                                                                                                             │             │        │          │                                                                       │             │      │          │                                                                                                           │             │      │          │                                                                                                                     │             │      │          │                                                                                                                                                                                             │             │        │          │                                                                                                         │             │        │          │                                                                                                                             │             │        │          │                                                                       │             │      │          │                                                                                                           │             │      │          │                                                                                                                     │             │      │          │                                                                                                                                                                                             │             │        │          │                                                                                                         │             │        │          │                                                                                                                             │             │        │          │                                                                       │             │      │          │                                                                                                           │             │      │          │                                                                                                                     │             │      │          │                                                                                                                                                                                             │             │        │          │                                                                                                         │             │        │          │                                                                                                                             │             │        │          │                                                                       │             │      │          │                                                                                                           │             │      │          │                                                                                                                     │             │      │           ...
# 1: ───XXYY^-0.064───#2^0───@^-0.127───×ᶠ──────────────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ──────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ────────────────────────────────Rz(-0.0π)───────────────────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ──────────────────────XXYY─────#2───────@─────×ᶠ────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ────────────────────────────────XXYY──────────#2───────@──────────×ᶠ────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ──────────────────────XXYY─────#2───────@─────×ᶠ──────────Rz(-0.0π)───XXYY^-0.064───#2^0───@^-0.127───×ᶠ──────────────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ──────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ────────────────────────────────Rz(-0.0π)───────────────────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ──────────────────────XXYY─────#2───────@─────×ᶠ────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ────────────────────────────────XXYY──────────#2───────@──────────×ᶠ────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ──────────────────────XXYY─────#2───────@─────×ᶠ──────────Rz(-0.0π)───XXYY^-0.064───#2^0───@^-0.127───×ᶠ──────────────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ──────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ────────────────────────────────Rz(-0.0π)───────────────────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ──────────────────────XXYY─────#2───────@─────×ᶠ────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ────────────────────────────────XXYY──────────#2───────@──────────×ᶠ────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ──────────────────────XXYY─────#2───────@─────×ᶠ──────────Rz(-0.0π)───XXYY^-0.064───#2^0───@^-0.127───×ᶠ──────────────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ──────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ────────────────────────────────Rz(-0.0π)───────────────────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ──────────────────────XXYY─────#2───────@─────×ᶠ────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ────────────────────────────────XXYY──────────#2───────@──────────×ᶠ────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ──────────────────────XXYY─────#2───────@─────×ᶠ──────────Rz(-0.0π)───XXYY^-0.064───#2^0───@^-0.127───×ᶠ──────────────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ──────────────────────────────XXYY^-0.064───#2^0───@^-0.127─── ...
#                                                                                                       │        │      │     │                                                                                                           │             │      │          │                                                                                                                     │        │      │     │                                                                                                                                                                           │        │        │     │                                                                                                                             │             │        │          │                                                                                                                   │        │        │     │                                                                                                                       │        │      │     │                                                                                                           │             │      │          │                                                                                                                     │        │      │     │                                                                                                                                                                           │        │        │     │                                                                                                                             │             │        │          │                                                                                                                   │        │        │     │                                                                                                                       │        │      │     │                                                                                                           │             │      │          │                                                                                                                     │        │      │     │                                                                                                                                                                           │        │        │     │                                                                                                                             │             │        │          │                                                                                                                   │        │        │     │                                                                                                                       │        │      │     │                                                                                                           │             │      │          │                                                                                                                     │        │      │     │                                                                                                                                                                           │        │        │     │                                                                                                                             │             │        │          │                                                                                                                   │        │        │     │                                                                                                                       │        │      │     │                                                                                                           │             │      │          │                                                                ...
# 2: ───────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ──────────────────────────────XXYY^0───#2^0───@^0───×ᶠ────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ──────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ──────────────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ──────────────────────────────XXYY^0───#2^0───@^0───×ᶠ────────────────────────────────Rz(-0.0π)─────────────────────────────────────XXYY──────────#2───────@──────────×ᶠ────────────────────────────────────────────────────────XXYY^0───YXXY^0───@^0───×ᶠ────────────────────────────────XXYY─────#2───────@─────×ᶠ──────────────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ────────────────────────────────XXYY─────#2───────@─────×ᶠ────────────────────────────────────────────────────────XXYY^0───YXXY^0───@^0───×ᶠ──────────Rz(-0.0π)───────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ──────────────────────────────XXYY^0───#2^0───@^0───×ᶠ────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ──────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ──────────────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ──────────────────────────────XXYY^0───#2^0───@^0───×ᶠ────────────────────────────────Rz(-0.0π)─────────────────────────────────────XXYY──────────#2───────@──────────×ᶠ────────────────────────────────────────────────────────XXYY^0───YXXY^0───@^0───×ᶠ────────────────────────────────XXYY─────#2───────@─────×ᶠ──────────────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ────────────────────────────────XXYY─────#2───────@─────×ᶠ────────────────────────────────────────────────────────XXYY^0───YXXY^0───@^0───×ᶠ──────────Rz(-0.0π)───────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ──────────────────────────────XXYY^0───#2^0───@^0───×ᶠ────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ──────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ──────────────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ──────────────────────────────XXYY^0───#2^0───@^0───×ᶠ────────────────────────────────Rz(-0.0π)─────────────────────────────────────XXYY──────────#2───────@──────────×ᶠ────────────────────────────────────────────────────────XXYY^0───YXXY^0───@^0───×ᶠ────────────────────────────────XXYY─────#2───────@─────×ᶠ──────────────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ────────────────────────────────XXYY─────#2───────@─────×ᶠ────────────────────────────────────────────────────────XXYY^0───YXXY^0───@^0───×ᶠ──────────Rz(-0.0π)───────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ──────────────────────────────XXYY^0───#2^0───@^0───×ᶠ────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ──────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ──────────────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ──────────────────────────────XXYY^0───#2^0───@^0───×ᶠ────────────────────────────────Rz(-0.0π)─────────────────────────────────────XXYY──────────#2───────@──────────×ᶠ────────────────────────────────────────────────────────XXYY^0───YXXY^0───@^0───×ᶠ────────────────────────────────XXYY─────#2───────@─────×ᶠ──────────────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ────────────────────────────────XXYY─────#2───────@─────×ᶠ────────────────────────────────────────────────────────XXYY^0───YXXY^0───@^0───×ᶠ──────────Rz(-0.0π)───────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ──────────────────────────────XXYY^0───#2^0───@^0───×ᶠ────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ──────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────────────── ...
#                                       │             │      │          │                                                                                                           │        │      │     │                                                                                                                               │        │      │     │                                                                                                                                     │             │        │          │                                                                                                                   │        │        │     │                                                                                                                                       │        │        │     │                                                                                                                                         │             │      │          │                                                                                                           │        │      │     │                                                                                                                               │        │      │     │                                                                                                                                     │             │        │          │                                                                                                                   │        │        │     │                                                                                                                                       │        │        │     │                                                                                                                                         │             │      │          │                                                                                                           │        │      │     │                                                                                                                               │        │      │     │                                                                                                                                     │             │        │          │                                                                                                                   │        │        │     │                                                                                                                                       │        │        │     │                                                                                                                                         │             │      │          │                                                                                                           │        │      │     │                                                                                                                               │        │      │     │                                                                                                                                     │             │        │          │                                                                                                                   │        │        │     │                                                                                                                                       │        │        │     │                                                                                                                                         │             │      │          │                                                                                                           │        │      │     │                                                                                                                                ...
# 3: ───────────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ──────────────────────────────XXYY^0───#2^0───@^0───×ᶠ──────────────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ──────────────────────────────XXYY^0───#2^0───@^0───×ᶠ────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ──────────Rz(-0.0π)─────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ────────────────────────────────XXYY─────#2───────@─────×ᶠ────────────────────────────────────────────────────────XXYY^0───YXXY^0───@^0───×ᶠ────────────────────────────────XXYY──────────#2───────@──────────×ᶠ──────────────────────────────────────────────────────────────────XXYY^0───YXXY^0───@^0───×ᶠ────────────────────────────────XXYY─────#2───────@─────×ᶠ──────────────────────────────────Rz(-0.0π)───────────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ──────────────────────────────XXYY^0───#2^0───@^0───×ᶠ──────────────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ──────────────────────────────XXYY^0───#2^0───@^0───×ᶠ────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ──────────Rz(-0.0π)─────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ────────────────────────────────XXYY─────#2───────@─────×ᶠ────────────────────────────────────────────────────────XXYY^0───YXXY^0───@^0───×ᶠ────────────────────────────────XXYY──────────#2───────@──────────×ᶠ──────────────────────────────────────────────────────────────────XXYY^0───YXXY^0───@^0───×ᶠ────────────────────────────────XXYY─────#2───────@─────×ᶠ──────────────────────────────────Rz(-0.0π)───────────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ──────────────────────────────XXYY^0───#2^0───@^0───×ᶠ──────────────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ──────────────────────────────XXYY^0───#2^0───@^0───×ᶠ────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ──────────Rz(-0.0π)─────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ────────────────────────────────XXYY─────#2───────@─────×ᶠ────────────────────────────────────────────────────────XXYY^0───YXXY^0───@^0───×ᶠ────────────────────────────────XXYY──────────#2───────@──────────×ᶠ──────────────────────────────────────────────────────────────────XXYY^0───YXXY^0───@^0───×ᶠ────────────────────────────────XXYY─────#2───────@─────×ᶠ──────────────────────────────────Rz(-0.0π)───────────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ──────────────────────────────XXYY^0───#2^0───@^0───×ᶠ──────────────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ──────────────────────────────XXYY^0───#2^0───@^0───×ᶠ────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ──────────Rz(-0.0π)─────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ────────────────────────────────XXYY─────#2───────@─────×ᶠ────────────────────────────────────────────────────────XXYY^0───YXXY^0───@^0───×ᶠ────────────────────────────────XXYY──────────#2───────@──────────×ᶠ──────────────────────────────────────────────────────────────────XXYY^0───YXXY^0───@^0───×ᶠ────────────────────────────────XXYY─────#2───────@─────×ᶠ──────────────────────────────────Rz(-0.0π)───────────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────XXYY─────YXXY───@─────×ᶠ──────────────────────────────XXYY^0───#2^0───@^0───×ᶠ──────────────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ────────────────────────────── ...
#                                                                                                                             │        │      │     │                                                                                                                     │             │      │          │                                                                                                           │        │      │     │                                                                                                                             │        │        │     │                                                                                                                   │             │        │          │                                                                                                                             │        │        │     │                                                                                                                                                                     │        │      │     │                                                                                                                     │             │      │          │                                                                                                           │        │      │     │                                                                                                                             │        │        │     │                                                                                                                   │             │        │          │                                                                                                                             │        │        │     │                                                                                                                                                                     │        │      │     │                                                                                                                     │             │      │          │                                                                                                           │        │      │     │                                                                                                                             │        │        │     │                                                                                                                   │             │        │          │                                                                                                                             │        │        │     │                                                                                                                                                                     │        │      │     │                                                                                                                     │             │      │          │                                                                                                           │        │      │     │                                                                                                                             │        │        │     │                                                                                                                   │             │        │          │                                                                                                                             │        │        │     │                                                                                                                                                                     │        │      │     │                                                                                                                     │             │      │          │                                ...
# 4: ───────────────────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ────────────────────XXYY^0───#2^0───@^0───×ᶠ────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ──────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ────────────────────XXYY^0───#2^0───@^0───×ᶠ──────────Rz(-0.0π)───XXYY──────────#2───────@──────────×ᶠ──────────────────────────────────────────────────────────────────XXYY^0───YXXY^0───@^0───×ᶠ──────────────────────XXYY──────────#2───────@──────────×ᶠ────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ────────────────────────────────XXYY──────────#2───────@──────────×ᶠ────────────────────────────────────────────────────────XXYY^0───YXXY^0───@^0───×ᶠ──────────────────────────────────Rz(-0.0π)───────────────────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ────────────────────XXYY^0───#2^0───@^0───×ᶠ────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ──────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ────────────────────XXYY^0───#2^0───@^0───×ᶠ──────────Rz(-0.0π)───XXYY──────────#2───────@──────────×ᶠ──────────────────────────────────────────────────────────────────XXYY^0───YXXY^0───@^0───×ᶠ──────────────────────XXYY──────────#2───────@──────────×ᶠ────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ────────────────────────────────XXYY──────────#2───────@──────────×ᶠ────────────────────────────────────────────────────────XXYY^0───YXXY^0───@^0───×ᶠ──────────────────────────────────Rz(-0.0π)───────────────────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ────────────────────XXYY^0───#2^0───@^0───×ᶠ────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ──────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ────────────────────XXYY^0───#2^0───@^0───×ᶠ──────────Rz(-0.0π)───XXYY──────────#2───────@──────────×ᶠ──────────────────────────────────────────────────────────────────XXYY^0───YXXY^0───@^0───×ᶠ──────────────────────XXYY──────────#2───────@──────────×ᶠ────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ────────────────────────────────XXYY──────────#2───────@──────────×ᶠ────────────────────────────────────────────────────────XXYY^0───YXXY^0───@^0───×ᶠ──────────────────────────────────Rz(-0.0π)───────────────────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ────────────────────XXYY^0───#2^0───@^0───×ᶠ────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ──────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ────────────────────XXYY^0───#2^0───@^0───×ᶠ──────────Rz(-0.0π)───XXYY──────────#2───────@──────────×ᶠ──────────────────────────────────────────────────────────────────XXYY^0───YXXY^0───@^0───×ᶠ──────────────────────XXYY──────────#2───────@──────────×ᶠ────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ────────────────────────────────XXYY──────────#2───────@──────────×ᶠ────────────────────────────────────────────────────────XXYY^0───YXXY^0───@^0───×ᶠ──────────────────────────────────Rz(-0.0π)───────────────────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ────────────────────XXYY^0───#2^0───@^0───×ᶠ────────────────────────────────────────────────────XXYY──────────YXXY───@──────────×ᶠ──────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────── ...
#                                                                       │             │      │          │                                                                                                 │             │      │          │                                                                                                                     │             │      │          │                                                                   │             │        │          │                                                                                                                   │             │        │          │                                                                                                                             │             │        │          │                                                                                                                                                                                                 │             │      │          │                                                                                                 │             │      │          │                                                                                                                     │             │      │          │                                                                   │             │        │          │                                                                                                                   │             │        │          │                                                                                                                             │             │        │          │                                                                                                                                                                                                 │             │      │          │                                                                                                 │             │      │          │                                                                                                                     │             │      │          │                                                                   │             │        │          │                                                                                                                   │             │        │          │                                                                                                                             │             │        │          │                                                                                                                                                                                                 │             │      │          │                                                                                                 │             │      │          │                                                                                                                     │             │      │          │                                                                   │             │        │          │                                                                                                                   │             │        │          │                                                                                                                             │             │        │          │                                                                                                                                                                                                 │             │      │          │                                                                                                 │             │      │          │                                                                                                ...
# 5: ───────────────────────────────────────────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ──────────────────────────────────────────Rz(-0.0π)───────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────Rz(-0.0π)───────────────────────────────────────────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ──────────────────────────────────────────Rz(-0.0π)───────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────Rz(-0.0π)───────────────────────────────────────────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ──────────────────────────────────────────Rz(-0.0π)───────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────Rz(-0.0π)───────────────────────────────────────────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ──────────────────────────────────────────Rz(-0.0π)───────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────XXYY^-0.064───YXXY^0───@^-0.127───×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────Rz(-0.0π)───────────────────────────────────────────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────────────────────────────────────────────────XXYY^-0.064───#2^0───@^-0.127───×ᶠ────────────────────────────────────────────────────────────────────────────────────────────── ...

# %%
# Create circuit
circuit = cirq.Circuit.from_ops(
    ofc.simulate_trotter(
        qubits, hubbard_hamiltonian, time,
        n_steps=1,
        order=0,
        algorithm=ofc.trotter.LINEAR_SWAP_NETWORK,
        omit_final_swaps=True),
    strategy=cirq.InsertStrategy.EARLIEST
)

cirq.DropNegligible().optimize_circuit(circuit)
print(circuit.to_text_diagram(transpose=True))
# Out:
# 0    1            2            3            4            5
# │    │            │            │            │            │
# XXYY─XXYY^(-7/11) XXYY─────────XXYY^(-7/11) XXYY─────────XXYY^(-7/11)
# │    │            │            │            │            │
# @────@^(8/11)     @────────────@^(8/11)     @────────────@^(8/11)
# │    │            │            │            │            │
# ×ᶠ───×ᶠ           ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ
# │    │            │            │            │            │
# │    ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ           │
# │    │            │            │            │            │
# XXYY─XXYY^(-7/11) │            │            XXYY─────────XXYY^(-7/11)
# │    │            │            │            │            │
# @────@^(8/11)     │            │            @────────────@^(8/11)
# │    │            │            │            │            │
# ×ᶠ───×ᶠ           ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ
# │    │            │            │            │            │
# │    XXYY─────────XXYY^(-7/11) XXYY─────────XXYY^(-7/11) │
# │    │            │            │            │            │
# │    @────────────@^(8/11)     @────────────@^(8/11)     │
# │    │            │            │            │            │
# │    ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ           │
# │    │            │            │            │            │
# XXYY─XXYY^(-7/11) │            │            XXYY─────────XXYY^(-7/11)
# │    │            │            │            │            │
# @────@^(8/11)     │            │            @────────────@^(8/11)
# │    │            │            │            │            │
# ×ᶠ───×ᶠ           ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ
# │    │            │            │            │            │
# │    ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ           │
# │    │            │            │            │            │

# %%
xmon_circuit = cirq.google.optimized_for_xmon(circuit)

print(xmon_circuit.to_text_diagram(transpose=True))
# Out:
# 0                      1                      2                      3                      4                      5
# │                      │                      │                      │                      │                      │
# PhasedX(-0.614)^0.5    │                      PhasedX(0.0784)^0.5    │                      PhasedX(-2.22e-15)^0.5 │
# │                      │                      │                      │                      │                      │
# @──────────────────────@                      @──────────────────────@                      @──────────────────────@
# │                      │                      │                      │                      │                      │
# PhasedX(0.386)^0.5     PhasedX(0.886)^(9/11)  PhasedX(-0.922)^0.5    PhasedX(-0.422)^(9/11) PhasedX(1.0)^0.5       Y^(-9/11)
# │                      │                      │                      │                      │                      │
# @──────────────────────@                      @──────────────────────@                      @──────────────────────@
# │                      │                      │                      │                      │                      │
# PhasedX(0.25)^0.5      PhasedX(-0.114)^(9/11) PhasedX(-0.0583)^0.5   PhasedX(0.578)^(9/11)  PhasedX(-0.137)^0.5    Y^(9/11)
# │                      │                      │                      │                      │                      │
# @──────────────────────@                      @──────────────────────@                      @──────────────────────@
# │                      │                      │                      │                      │                      │
# PhasedX(-0.25)^0.726   PhasedX(0.887)^0.5     PhasedX(-0.558)^(9/13) PhasedX(0.887)^0.5     PhasedX(-0.637)^0.613  │
# │                      │                      │                      │                      │                      │
# │                      @──────────────────────@                      @──────────────────────@                      │
# │                      │                      │                      │                      │                      │
# │                      PhasedX(-0.113)^0.5    PhasedX(-0.0583)^0.5   PhasedX(0.887)^0.5     PhasedX(0.863)^0.5     │
# │                      │                      │                      │                      │                      │
# │                      @──────────────────────@                      @──────────────────────@                      │
# │                      │                      │                      │                      │                      │
# │                      PhasedX(-0.113)^0.5    @──────────────────────@                      PhasedX(-0.637)^(3/14) │
# │                      │                      │                      │                      │                      │
# @──────────────────────@                      PhasedX(0.942)^0.5     PhasedX(0.887)^0.5     @──────────────────────@
# │                      │                      │                      │                      │                      │
# PhasedX(-0.75)^0.5     PhasedX(0.661)^(9/11)  @──────────────────────@                      PhasedX(0.863)^0.5     PhasedX(0.173)^(9/11)
# │                      │                      │                      │                      │                      │
# @──────────────────────@                      PhasedX(-0.0583)^0.5   PhasedX(0.387)^0.775   @──────────────────────@
# │                      │                      │                      │                      │                      │
# PhasedX(-0.887)^0.5    PhasedX(-0.339)^(9/11) │                      │                      PhasedX(0.727)^0.5     PhasedX(-0.827)^(9/11)
# │                      │                      │                      │                      │                      │
# @──────────────────────@                      │                      │                      @──────────────────────@
# │                      │                      │                      │                      │                      │
# PhasedX(0.613)^0.00111 PhasedX(-0.175)^0.5    │                      │                      PhasedX(0.727)^0.5     │
# │                      │                      │                      │                      │                      │
# │                      @──────────────────────@                      @──────────────────────@                      │
# │                      │                      │                      │                      │                      │
# │                      PhasedX(0.825)^0.5     PhasedX(-0.86)^(9/11)  PhasedX(-0.113)^0.5    PhasedX(-0.849)^(9/11) │
# │                      │                      │                      │                      │                      │
# │                      @──────────────────────@                      @──────────────────────@                      │
# │                      │                      │                      │                      │                      │
# │                      PhasedX(-0.0383)^0.5   PhasedX(-0.86)^(9/11)  PhasedX(-0.977)^0.5    PhasedX(-0.849)^(9/11) │
# │                      │                      │                      │                      │                      │
# │                      @──────────────────────@                      @──────────────────────@                      │
# │                      │                      │                      │                      │                      │
# │                      PhasedX(0.962)^0.5     PhasedX(-0.195)^0.5    PhasedX(0.523)^0.0888  PhasedX(-0.51)^0.5     │
# │                      │                      │                      │                      │                      │
# @──────────────────────@                      @──────────────────────@                      @──────────────────────@
# │                      │                      │                      │                      │                      │
# PhasedX(0.113)^0.5     PhasedX(-0.567)^(9/11) PhasedX(-0.195)^0.5    PhasedX(-0.977)^0.5    PhasedX(-0.51)^0.5     PhasedX(0.773)^(-9/11)
# │                      │                      │                      │                      │                      │
# @──────────────────────@                      @──────────────────────@                      @──────────────────────@
# │                      │                      │                      │                      │                      │
# PhasedX(-0.0236)^0.5   PhasedX(0.433)^(9/11)  │                      │                      PhasedX(0.353)^0.5     PhasedX(0.773)^(9/11)
# │                      │                      │                      │                      │                      │
# @──────────────────────@                      │                      │                      @──────────────────────@
# │                      │                      │                      │                      │                      │
# PhasedX(0.976)^0.5     PhasedX(-0.567)^0.5    │                      │                      PhasedX(-0.147)^0.613  Z^(1/11)
# │                      │                      │                      │                      │                      │
# Z^-0.227               @──────────────────────@                      @──────────────────────@                      │
# │                      │                      │                      │                      │                      │
# │                      PhasedX(-0.567)^0.5    PhasedX(-0.195)^0.5    PhasedX(0.0232)^0.5    PhasedX(0.353)^0.5     │
# │                      │                      │                      │                      │                      │
# │                      @──────────────────────@                      @──────────────────────@                      │
# │                      │                      │                      │                      │                      │
# │                      PhasedX(-0.567)^0.5    PhasedX(0.805)^0.5     PhasedX(-0.977)^0.5    PhasedX(-0.647)^0.5    │
# │                      │                      │                      │                      │                      │
# │                      PhasedX(-0.908)        PhasedX(-0.695)        PhasedX(0.705)         Z^0.897                │
# │                      │                      │                      │                      │                      │
# │                      │                      Z^(4/9)                Z^(4/11)               │                      │
# │                      │                      │                      │                      │                      │

# %%
two_qubit_gates = xmon_circuit.findall_operations_with_gate_type(cirq.TwoQubitGate)
print(len(list(two_qubit_gates)))
# Out:
# 39

# %%
ansatz = ofc.SwapNetworkTrotterAnsatz(
    hubbard_hamiltonian,
    iterations=3)
print(ansatz.circuit.to_text_diagram(transpose=True))
# Out:
# 0    1            2            3            4            5
# │    │            │            │            │            │
# XXYY─XXYY^T_0_1_0 XXYY─────────XXYY^T_2_3_0 XXYY─────────XXYY^T_4_5_0
# │    │            │            │            │            │
# @────@^V_0_1_0    @────────────@^V_2_3_0    @────────────@^V_4_5_0
# │    │            │            │            │            │
# ×ᶠ───×ᶠ           ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ
# │    │            │            │            │            │
# │    ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ           │
# │    │            │            │            │            │
# XXYY─XXYY^T_1_3_0 ×ᶠ───────────×ᶠ           XXYY─────────XXYY^T_2_4_0
# │    │            │            │            │            │
# @────@^V_1_3_0    │            │            @────────────@^V_2_4_0
# │    │            │            │            │            │
# ×ᶠ───×ᶠ           │            │            ×ᶠ───────────×ᶠ
# │    │            │            │            │            │
# │    XXYY─────────XXYY^T_1_5_0 XXYY─────────XXYY^T_0_4_0 │
# │    │            │            │            │            │
# │    @────────────@^V_1_5_0    @────────────@^V_0_4_0    │
# │    │            │            │            │            │
# │    ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ           │
# │    │            │            │            │            │
# XXYY─XXYY^T_3_5_0 ×ᶠ───────────×ᶠ           XXYY─────────XXYY^T_0_2_0
# │    │            │            │            │            │
# @────@^V_3_5_0    │            │            @────────────@^V_0_2_0
# │    │            │            │            │            │
# ×ᶠ───×ᶠ           │            │            ×ᶠ───────────×ᶠ
# │    │            │            │            │            │
# │    ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ           │
# │    │            │            │            │            │
# │    ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ           │
# │    │            │            │            │            │
# @────@^V_3_5_0    ×ᶠ───────────×ᶠ           @────────────@^V_0_2_0
# │    │            │            │            │            │
# XXYY─XXYY^T_3_5_0 │            │            XXYY─────────XXYY^T_0_2_0
# │    │            │            │            │            │
# ×ᶠ───×ᶠ           │            │            ×ᶠ───────────×ᶠ
# │    │            │            │            │            │
# │    @────────────@^V_1_5_0    @────────────@^V_0_4_0    │
# │    │            │            │            │            │
# │    XXYY─────────XXYY^T_1_5_0 XXYY─────────XXYY^T_0_4_0 │
# │    │            │            │            │            │
# │    ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ           │
# │    │            │            │            │            │
# @────@^V_1_3_0    ×ᶠ───────────×ᶠ           @────────────@^V_2_4_0
# │    │            │            │            │            │
# XXYY─XXYY^T_1_3_0 │            │            XXYY─────────XXYY^T_2_4_0
# │    │            │            │            │            │
# ×ᶠ───×ᶠ           │            │            ×ᶠ───────────×ᶠ
# │    │            │            │            │            │
# │    ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ           │
# │    │            │            │            │            │
# @────@^V_0_1_0    @────────────@^V_2_3_0    @────────────@^V_4_5_0
# │    │            │            │            │            │
# XXYY─XXYY^T_0_1_0 XXYY─────────XXYY^T_2_3_0 XXYY─────────XXYY^T_4_5_0
# │    │            │            │            │            │
# ×ᶠ───×ᶠ           ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ
# │    │            │            │            │            │
# XXYY─XXYY^T_0_1_1 XXYY─────────XXYY^T_2_3_1 XXYY─────────XXYY^T_4_5_1
# │    │            │            │            │            │
# @────@^V_0_1_1    @────────────@^V_2_3_1    @────────────@^V_4_5_1
# │    │            │            │            │            │
# ×ᶠ───×ᶠ           ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ
# │    │            │            │            │            │
# │    ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ           │
# │    │            │            │            │            │
# XXYY─XXYY^T_1_3_1 ×ᶠ───────────×ᶠ           XXYY─────────XXYY^T_2_4_1
# │    │            │            │            │            │
# @────@^V_1_3_1    │            │            @────────────@^V_2_4_1
# │    │            │            │            │            │
# ×ᶠ───×ᶠ           │            │            ×ᶠ───────────×ᶠ
# │    │            │            │            │            │
# │    XXYY─────────XXYY^T_1_5_1 XXYY─────────XXYY^T_0_4_1 │
# │    │            │            │            │            │
# │    @────────────@^V_1_5_1    @────────────@^V_0_4_1    │
# │    │            │            │            │            │
# │    ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ           │
# │    │            │            │            │            │
# XXYY─XXYY^T_3_5_1 ×ᶠ───────────×ᶠ           XXYY─────────XXYY^T_0_2_1
# │    │            │            │            │            │
# @────@^V_3_5_1    │            │            @────────────@^V_0_2_1
# │    │            │            │            │            │
# ×ᶠ───×ᶠ           │            │            ×ᶠ───────────×ᶠ
# │    │            │            │            │            │
# │    ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ           │
# │    │            │            │            │            │
# │    ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ           │
# │    │            │            │            │            │
# @────@^V_3_5_1    ×ᶠ───────────×ᶠ           @────────────@^V_0_2_1
# │    │            │            │            │            │
# XXYY─XXYY^T_3_5_1 │            │            XXYY─────────XXYY^T_0_2_1
# │    │            │            │            │            │
# ×ᶠ───×ᶠ           │            │            ×ᶠ───────────×ᶠ
# │    │            │            │            │            │
# │    @────────────@^V_1_5_1    @────────────@^V_0_4_1    │
# │    │            │            │            │            │
# │    XXYY─────────XXYY^T_1_5_1 XXYY─────────XXYY^T_0_4_1 │
# │    │            │            │            │            │
# │    ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ           │
# │    │            │            │            │            │
# @────@^V_1_3_1    ×ᶠ───────────×ᶠ           @────────────@^V_2_4_1
# │    │            │            │            │            │
# XXYY─XXYY^T_1_3_1 │            │            XXYY─────────XXYY^T_2_4_1
# │    │            │            │            │            │
# ×ᶠ───×ᶠ           │            │            ×ᶠ───────────×ᶠ
# │    │            │            │            │            │
# │    ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ           │
# │    │            │            │            │            │
# @────@^V_0_1_1    @────────────@^V_2_3_1    @────────────@^V_4_5_1
# │    │            │            │            │            │
# XXYY─XXYY^T_0_1_1 XXYY─────────XXYY^T_2_3_1 XXYY─────────XXYY^T_4_5_1
# │    │            │            │            │            │
# ×ᶠ───×ᶠ           ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ
# │    │            │            │            │            │
# XXYY─XXYY^T_0_1_2 XXYY─────────XXYY^T_2_3_2 XXYY─────────XXYY^T_4_5_2
# │    │            │            │            │            │
# @────@^V_0_1_2    @────────────@^V_2_3_2    @────────────@^V_4_5_2
# │    │            │            │            │            │
# ×ᶠ───×ᶠ           ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ
# │    │            │            │            │            │
# │    ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ           │
# │    │            │            │            │            │
# XXYY─XXYY^T_1_3_2 ×ᶠ───────────×ᶠ           XXYY─────────XXYY^T_2_4_2
# │    │            │            │            │            │
# @────@^V_1_3_2    │            │            @────────────@^V_2_4_2
# │    │            │            │            │            │
# ×ᶠ───×ᶠ           │            │            ×ᶠ───────────×ᶠ
# │    │            │            │            │            │
# │    XXYY─────────XXYY^T_1_5_2 XXYY─────────XXYY^T_0_4_2 │
# │    │            │            │            │            │
# │    @────────────@^V_1_5_2    @────────────@^V_0_4_2    │
# │    │            │            │            │            │
# │    ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ           │
# │    │            │            │            │            │
# XXYY─XXYY^T_3_5_2 ×ᶠ───────────×ᶠ           XXYY─────────XXYY^T_0_2_2
# │    │            │            │            │            │
# @────@^V_3_5_2    │            │            @────────────@^V_0_2_2
# │    │            │            │            │            │
# ×ᶠ───×ᶠ           │            │            ×ᶠ───────────×ᶠ
# │    │            │            │            │            │
# │    ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ           │
# │    │            │            │            │            │
# │    ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ           │
# │    │            │            │            │            │
# @────@^V_3_5_2    ×ᶠ───────────×ᶠ           @────────────@^V_0_2_2
# │    │            │            │            │            │
# XXYY─XXYY^T_3_5_2 │            │            XXYY─────────XXYY^T_0_2_2
# │    │            │            │            │            │
# ×ᶠ───×ᶠ           │            │            ×ᶠ───────────×ᶠ
# │    │            │            │            │            │
# │    @────────────@^V_1_5_2    @────────────@^V_0_4_2    │
# │    │            │            │            │            │
# │    XXYY─────────XXYY^T_1_5_2 XXYY─────────XXYY^T_0_4_2 │
# │    │            │            │            │            │
# │    ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ           │
# │    │            │            │            │            │
# @────@^V_1_3_2    ×ᶠ───────────×ᶠ           @────────────@^V_2_4_2
# │    │            │            │            │            │
# XXYY─XXYY^T_1_3_2 │            │            XXYY─────────XXYY^T_2_4_2
# │    │            │            │            │            │
# ×ᶠ───×ᶠ           │            │            ×ᶠ───────────×ᶠ
# │    │            │            │            │            │
# │    ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ           │
# │    │            │            │            │            │
# @────@^V_0_1_2    @────────────@^V_2_3_2    @────────────@^V_4_5_2
# │    │            │            │            │            │
# XXYY─XXYY^T_0_1_2 XXYY─────────XXYY^T_2_3_2 XXYY─────────XXYY^T_4_5_2
# │    │            │            │            │            │
# ×ᶠ───×ᶠ           ×ᶠ───────────×ᶠ           ×ᶠ───────────×ᶠ
# │    │            │            │            │            │

# %%
import openfermion as of
# Set Hubbard model parameters
x_dim = 2
y_dim = 3
tunneling = 1.0
coulomb = 4.0
spinless=True

# Create Hubbard model Hamiltonian as FermionOperator
hubbard_model = of.fermi_hubbard(x_dim, y_dim, tunneling, coulomb, spinless=spinless)
print(hubbard_model)

from openfermion.transforms import get_sparse_operator
n_electrons = 2

# Compute the ground state energy at the specified number of electrons
hamiltonian_sparse = get_sparse_operator(hubbard_model)
true_ground_energy, _ = of.jw_get_ground_state_at_particle_number(
    hamiltonian_sparse, n_electrons)

print(true_ground_energy)
# Out:
# 4.0 [0^ 0 1^ 1] +
# 4.0 [0^ 0 2^ 2] +
# -1.0 [0^ 1] +
# -1.0 [0^ 2] +
# -1.0 [0^ 4] +
# -1.0 [1^ 0] +
# 4.0 [1^ 1 3^ 3] +
# -1.0 [1^ 3] +
# -1.0 [1^ 5] +
# -1.0 [2^ 0] +
# 4.0 [2^ 2 3^ 3] +
# 4.0 [2^ 2 4^ 4] +
# -1.0 [2^ 3] +
# -1.0 [2^ 4] +
# -1.0 [3^ 1] +
# -1.0 [3^ 2] +
# 4.0 [3^ 3 5^ 5] +
# -1.0 [3^ 5] +
# -1.0 [4^ 0] +
# -1.0 [4^ 2] +
# 4.0 [4^ 4 0^ 0] +
# 4.0 [4^ 4 5^ 5] +
# -1.0 [4^ 5] +
# -1.0 [5^ 1] +
# -1.0 [5^ 3] +
# -1.0 [5^ 4] +
# 4.0 [5^ 5 1^ 1]
# -3.1231056256176655

# %%
import openfermion as of

# %%
x_dim = 2
y_dim = 3
tunneling = 1.0
coulomb = 4.0
spinless=True
# Create Hubbard model Hamiltonian as FermionOperator
hubbard_model = of.fermi_hubbard(x_dim, y_dim, tunneling, coulomb, spinless=spinless)
print(hubbard_model)
# Out:
# 4.0 [0^ 0 1^ 1] +
# 4.0 [0^ 0 2^ 2] +
# -1.0 [0^ 1] +
# -1.0 [0^ 2] +
# -1.0 [0^ 4] +
# -1.0 [1^ 0] +
# 4.0 [1^ 1 3^ 3] +
# -1.0 [1^ 3] +
# -1.0 [1^ 5] +
# -1.0 [2^ 0] +
# 4.0 [2^ 2 3^ 3] +
# 4.0 [2^ 2 4^ 4] +
# -1.0 [2^ 3] +
# -1.0 [2^ 4] +
# -1.0 [3^ 1] +
# -1.0 [3^ 2] +
# 4.0 [3^ 3 5^ 5] +
# -1.0 [3^ 5] +
# -1.0 [4^ 0] +
# -1.0 [4^ 2] +
# 4.0 [4^ 4 0^ 0] +
# 4.0 [4^ 4 5^ 5] +
# -1.0 [4^ 5] +
# -1.0 [5^ 1] +
# -1.0 [5^ 3] +
# -1.0 [5^ 4] +
# 4.0 [5^ 5 1^ 1]

# %%
from openfermion.transforms import get_sparse_operator
hamiltonian_sparse = get_sparse_operator(hubbard_model)
print(hamiltonian_sparse)
# Out:
#   (2, 1)	(-1+0j)
#   (4, 1)	(-1+0j)
#   (16, 1)	(-1+0j)
#   (1, 2)	(-1+0j)
#   (8, 2)	(-1+0j)
#   (32, 2)	(-1+0j)
#   (3, 3)	(4+0j)
#   (6, 3)	(1+0j)
#   (9, 3)	(-1+0j)
#   (18, 3)	(1+0j)
#   (33, 3)	(-1+0j)
#   (1, 4)	(-1+0j)
#   (8, 4)	(-1+0j)
#   (16, 4)	(-1+0j)
#   (5, 5)	(4+0j)
#   (6, 5)	(-1+0j)
#   (9, 5)	(-1+0j)
#   (17, 5)	(-1+0j)
#   (20, 5)	(1+0j)
#   (3, 6)	(1+0j)
#   (5, 6)	(-1+0j)
#   (10, 6)	(-1+0j)
#   (12, 6)	(1+0j)
#   (18, 6)	(-1+0j)
#   (36, 6)	(1+0j)
#   :	:
#   (58, 57)	(-1+0j)
#   (60, 57)	(-1+0j)
#   (43, 58)	(-1+0j)
#   (46, 58)	(1+0j)
#   (54, 58)	(-1+0j)
#   (57, 58)	(-1+0j)
#   (58, 58)	(16+0j)
#   (47, 59)	(1+0j)
#   (55, 59)	(-1+0j)
#   (59, 59)	(24+0j)
#   (62, 59)	(1+0j)
#   (30, 60)	(1+0j)
#   (45, 60)	(-1+0j)
#   (54, 60)	(1+0j)
#   (57, 60)	(-1+0j)
#   (60, 60)	(16+0j)
#   (31, 61)	(1+0j)
#   (55, 61)	(1+0j)
#   (61, 61)	(24+0j)
#   (62, 61)	(-1+0j)
#   (47, 62)	(1+0j)
#   (59, 62)	(1+0j)
#   (61, 62)	(-1+0j)
#   (62, 62)	(24+0j)
#   (63, 63)	(36+0j)

# %%
n_electrons = 2
true_ground_energy, _ = of.jw_get_ground_state_at_particle_number(hamiltonian_sparse, n_electrons)

print(true_ground_energy)
# Out:
# -3.12310562561766

# %%
import openfermion

diatomic_bond_length = .7414
geometry = [('H', (0., 0., 0.)), 
            ('H', (0., 0., diatomic_bond_length))]
basis = 'sto-3g'
multiplicity = 1
charge = 0
description = format(diatomic_bond_length)

molecule = openfermion.MolecularData(
    geometry,
    basis,
    multiplicity,
    description=description)
molecule.load()

hamiltonian = molecule.get_molecular_hamiltonian()
print("Bond Length in Angstroms: {}".format(diatomic_bond_length))
print("Hartree Fock (mean-field) energy in Hartrees: {}".format(molecule.hf_energy))
print("FCI (Exact) energy in Hartrees: {}".format(molecule.fci_energy))
# Out:
# Bond Length in Angstroms: 0.7414
# Hartree Fock (mean-field) energy in Hartrees: -1.116684386906734
# FCI (Exact) energy in Hartrees: -1.137270174625328

# %%
import cirq
import openfermioncirq
import sympy

class MyAnsatz(openfermioncirq.VariationalAnsatz):
    
    def params(self):
        """The parameters of the ansatz."""
        return [sympy.Symbol('theta_0')]
    
    def operations(self, qubits):
        """Produce the operations of the ansatz circuit."""
        q0, q1, q2, q3 = qubits
        yield cirq.H(q0), cirq.H(q1), cirq.H(q2)
        yield cirq.XPowGate(exponent=-0.5).on(q3)
        
        yield cirq.CNOT(q0, q1), cirq.CNOT(q1, q2), cirq.CNOT(q2, q3)
        yield cirq.ZPowGate(exponent=sympy.Symbol('theta_0')).on(q3)
        yield cirq.CNOT(q2, q3), cirq.CNOT(q1, q2), cirq.CNOT(q0, q1)
        
        yield cirq.H(q0), cirq.H(q1), cirq.H(q2)
        yield cirq.XPowGate(exponent=0.5).on(q3)

    def _generate_qubits(self):
        """Produce qubits that can be used by the ansatz circuit."""
        return cirq.LineQubit.range(4)

# %%
ansatz = MyAnsatz()
objective = openfermioncirq.HamiltonianObjective(hamiltonian)
q0, q1, _, _ = ansatz.qubits
preparation_circuit = cirq.Circuit.from_ops(
    cirq.X(q0),
    cirq.X(q1))
study = openfermioncirq.VariationalStudy(
    name='my_hydrogen_study',
    ansatz=ansatz,
    objective=objective,
    preparation_circuit=preparation_circuit)
print(study.circuit)
print(study.num_params)
# Out:
# 0: ───X───H────────@───────────────────────────────────@───H───
#                    │                                   │
# 1: ───X───H────────X───@───────────────────────@───────X───H───
#                        │                       │
# 2: ───────H────────────X───@───────────────@───X───────H───────
#                            │               │
# 3: ───────X^-0.5───────────X───Z^theta_0───X───X^0.5───────────
# 1

# %%
# Perform optimization.
import numpy
import openfermioncirq as ofc
from openfermioncirq.optimization import COBYLA, OptimizationParams
algorithm=ofc.optimization.ScipyOptimizationAlgorithm(kwargs={'method': 'COBYLA'},uses_bounds=False)
optimization_params = OptimizationParams(algorithm=algorithm,initial_guess=[0.1])
result = study.optimize(optimization_params)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-fe350fd14f4f> in <module>
#       5 algorithm=ofc.optimization.ScipyOptimizationAlgorithm(kwargs={'method': 'COBYLA'},uses_bounds=False)
#       6 optimization_params = OptimizationParams(algorithm=algorithm,initial_guess=[0.1])
# ----> 7 result = study.optimize(optimization_params)
#       8
#       9
#
# ~/yes/envs/openfermion/lib/python3.6/site-packages/openfermioncirq/variational/study.py in optimize(self, optimization_params, identifier, reevaluate_final_params, save_x_vals, repetitions, seeds, use_multiprocessing, num_processes)
#     171                                    seeds,
#     172                                    use_multiprocessing,
# --> 173                                    num_processes)[0]
#     174
#     175     def optimize_sweep(self,
#
# ~/yes/envs/openfermion/lib/python3.6/site-packages/openfermioncirq/variational/study.py in optimize_sweep(self, param_sweep, identifiers, reevaluate_final_params, save_x_vals, repetitions, seeds, use_multiprocessing, num_processes)
#     257                         seeds,
#     258                         use_multiprocessing,
# --> 259                         num_processes)
#     260
#     261                 trial_result = OptimizationTrialResult(result_list,
#
# ~/yes/envs/openfermion/lib/python3.6/site-packages/openfermioncirq/variational/study.py in _get_result_list(self, optimization_params, reevaluate_final_params, save_x_vals, repetitions, seeds, use_multiprocessing, num_processes)
#     423                         else numpy.random.randint(4294967296),
#     424                         self.ansatz.default_initial_params(),
# --> 425                         self._black_box_type
#     426                     )
#     427                 )
#
# ~/yes/envs/openfermion/lib/python3.6/site-packages/openfermioncirq/variational/study.py in _run_optimization(args)
#     619     result = optimization_params.algorithm.optimize(black_box,
#     620                                                     initial_guess,
# --> 621                                                     initial_guess_array)
#     622     t1 = time.time()
#     623
#
# ~/yes/envs/openfermion/lib/python3.6/site-packages/openfermioncirq/optimization/scipy.py in optimize(self, black_box, initial_guess, initial_guess_array)
#      57                                          bounds=bounds,
#      58                                          options=self.options,
# ---> 59                                          **self.kwargs)
#      60         return OptimizationResult(optimal_value=result.fun,
#      61                                   optimal_parameters=result.x,
#
# ~/yes/envs/openfermion/lib/python3.6/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     604                              **options)
#     605     elif meth == 'cobyla':
# --> 606         return _minimize_cobyla(fun, x0, args, constraints, **options)
#     607     elif meth == 'slsqp':
#     608         return _minimize_slsqp(fun, x0, args, jac, bounds,
#
# ~/yes/envs/openfermion/lib/python3.6/site-packages/scipy/optimize/cobyla.py in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, **unknown_options)
#     250     xopt, info = _cobyla.minimize(calcfc, m=m, x=np.copy(x0), rhobeg=rhobeg,
#     251                                   rhoend=rhoend, iprint=iprint, maxfun=maxfun,
# --> 252                                   dinfo=info)
#     253
#     254     if info[3] > catol:
#
# ~/yes/envs/openfermion/lib/python3.6/site-packages/scipy/optimize/cobyla.py in calcfc(x, con)
#     240
#     241     def calcfc(x, con):
# --> 242         f = fun(x, *args)
#     243         i = 0
#     244         for size, c in izip(cons_lengths, constraints):
#
# ~/yes/envs/openfermion/lib/python3.6/site-packages/openfermioncirq/optimization/black_box.py in evaluate(self, x)
#     100         if self.cost_of_evaluate is not None:
#     101             return self.evaluate_with_cost(x, self.cost_of_evaluate)
# --> 102         return self._evaluate(x)
#     103
#     104     def evaluate_with_cost(self,
#
# ~/yes/envs/openfermion/lib/python3.6/site-packages/openfermioncirq/variational/variational_black_box.py in _evaluate(self, x)
#      70         """Determine the value of some parameters."""
#      71         # Default: defer to evaluate_noiseless
# ---> 72         return self.evaluate_noiseless(x)
#      73
#      74     def _evaluate_with_cost(self,
#
# ~/yes/envs/openfermion/lib/python3.6/site-packages/openfermioncirq/variational/variational_black_box.py in evaluate_noiseless(self, x)
#      98         final_state = circuit.apply_unitary_effect_to_state(
#      99                 self.initial_state,
# --> 100                 qubit_order=self.ansatz.qubit_permutation(self.ansatz.qubits))
#     101         return self.objective.value(final_state)
#     102
#
# ~/yes/envs/openfermion/lib/python3.6/site-packages/cirq/circuits/circuit.py in apply_unitary_effect_to_state(self, initial_state, qubit_order, qubits_that_should_be_present, ignore_terminal_measurements, dtype)
#    1265         state.shape = (2,) * n
#    1266
# -> 1267         result = _apply_unitary_circuit(self, state, qs, dtype)
#    1268         return result.reshape((1 << n,))
#    1269
#
# ~/yes/envs/openfermion/lib/python3.6/site-packages/cirq/circuits/circuit.py in _apply_unitary_circuit(circuit, state, qubits, dtype)
#    1638         result = protocols.apply_unitary(
#    1639             unitary_value=op,
# -> 1640             args=protocols.ApplyUnitaryArgs(state, buffer, indices))
#    1641         if result is buffer:
#    1642             buffer = state
#
# ~/yes/envs/openfermion/lib/python3.6/site-packages/cirq/protocols/apply_unitary.py in apply_unitary(unitary_value, args, default)
#     206     func = getattr(unitary_value, '_apply_unitary_', None)
#     207     if func is not None:
# --> 208         result = func(args)
#     209         if result is not NotImplemented and result is not None:
#     210             return result
#
# ~/yes/envs/openfermion/lib/python3.6/site-packages/cirq/ops/gate_operation.py in _apply_unitary_(self, args)
#     105             self.gate,
#     106             args,
# --> 107             default=NotImplemented)
#     108
#     109     def _has_unitary_(self) -> bool:
#
# ~/yes/envs/openfermion/lib/python3.6/site-packages/cirq/protocols/apply_unitary.py in apply_unitary(unitary_value, args, default)
#     206     func = getattr(unitary_value, '_apply_unitary_', None)
#     207     if func is not None:
# --> 208         result = func(args)
#     209         if result is not NotImplemented and result is not None:
#     210             return result
#
# ~/yes/envs/openfermion/lib/python3.6/site-packages/cirq/ops/common_gates.py in _apply_unitary_(self, args)
#     241         one = args.subspace_index(1)
#     242         c = 1j**(self._exponent * 2)
# --> 243         args.target_tensor[one] *= c
#     244         p = 1j**(2 * self._exponent * self._global_shift)
#     245         if p != 1:
#
# TypeError: ufunc 'multiply' output (typecode 'O') could not be coerced to provided output parameter (typecode 'D') according to the casting rule ''same_kind''
